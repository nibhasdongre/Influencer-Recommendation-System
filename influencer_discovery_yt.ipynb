# %%
# !pip install --upgrade google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (2.192.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client) (0.31.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client) (2.47.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.72.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.3.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.2.25)

# %%
# !pip install --upgrade google-auth-oauthlib google-auth-httplib2
# Out:
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib) (2.47.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-httplib2) (0.31.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-auth-httplib2) (3.3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.43.0,!=2.44.0,!=2.45.0,<3.0.0,>=2.15.0->google-auth-oauthlib) (0.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2026.2.25)

# %%
# !pip install apify-client
# Out:
# Collecting apify-client
#   Downloading apify_client-2.5.0-py3-none-any.whl.metadata (18 kB)
# Collecting apify-shared<3.0.0,>=2.1.0 (from apify-client)
#   Downloading apify_shared-2.2.0-py3-none-any.whl.metadata (14 kB)
# Collecting colorama>=0.4.0 (from apify-client)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting impit>=0.9.2 (from apify-client)
#   Downloading impit-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: more-itertools>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from apify-client) (10.8.0)
# Downloading apify_client-2.5.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 3.4 MB/s eta 0:00:00
# Downloading apify_shared-2.2.0-py3-none-any.whl (16 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading impit-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 56.2 MB/s eta 0:00:00
# Installing collected packages: impit, colorama, apify-shared, apify-client
# Successfully installed apify-client-2.5.0 apify-shared-2.2.0 colorama-0.4.6 impit-0.12.0

# %%
import csv
from googleapiclient.discovery import build

# 1. Setup API
api_key = "AIzaSyC8d9CYsuZJasGTLJCHyV1fpr5V8_YQauQ"
youtube = build('youtube', 'v3', developerKey=api_key)

# 2. Read Keywords from the .txt file
def load_keywords(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return [line.strip() for line in f if line.strip()]

keywords = load_keywords("/fitness-keywords.txt")

# 3. Define the CSV output
output_file = "youtube_creators.csv"
headers = ["Keyword", "Channel ID", "Channel Title","PublishedAt","Thumbnail URL",
    "Language",
    "Subscriber Count",
    "Video Count"]

print(f"Reading {len(keywords)} keywords. Saving results to {output_file}...")

# 4. Open CSV and execute search
with open(output_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(headers)

    for keyword in keywords:
        print(f"Searching: {keyword}")

        try:
            request = youtube.search().list(
                q=keyword,
                part="snippet",
                type="video",
                maxResults=10
            )
            response = request.execute()

            for item in response.get('items', []):
                channel_id = item['snippet']['channelId']
                channel_title = item['snippet']['channelTitle']
                publishedAt=item['snippet']['publishedAt']
                # Clean description to prevent CSV formatting issues
                description = item['snippet']['description'].replace('\n', ' ').replace('\r', '')

                writer.writerow([keyword, channel_id, channel_title, description])

        except Exception as e:
            print(f"Error searching for '{keyword}': {e}")

print("Extraction complete!")
# Out:
# Reading 22 keywords. Saving results to youtube_creators.csv...
# Searching: fitness workout routine
# Searching: home workout routine
# Searching: gym workout routine
# Searching: full body workout
# Searching: fat loss workout
# Searching: muscle building workout
# Searching: bodyweight workout
# Searching: HIIT workout
# Searching: fitness trainer tips
# Searching: workout for beginners
# Searching: fitness diet plan
# Searching: healthy meal prep
# Searching: high protein recipes
# Searching: muscle gain diet
# Searching: fat loss diet
# Searching: fitness nutrition tips
# Searching: healthy breakfast recipes
# Searching: fitness meal prep
# Searching: high protein vegetarian recipes
# Searching: fitness lifestyle
# Searching: gym diet plan
# Searching: fitness daily routine
# Extraction complete!

# %%
import csv
from apify_client import ApifyClient
API_TOKEN = "apify_api_7maeczNL4l6O8S1lQngVDlrbcnV9Ck2VVpkM"
HASHTAG_FILE = "/content/fitness-keyowords-instagram.txt"
OUTPUT_FILE = "instagram_creators.csv"

TOP_K_POSTS = 20

client = ApifyClient(API_TOKEN)

# read hashtags
with open(HASHTAG_FILE) as f:
    hashtags = [line.strip().replace("#","") for line in f if line.strip()]

usernames = set()

for hashtag in hashtags:

    print(f"Searching #{hashtag}")

    hashtag_url = f"https://www.instagram.com/explore/tags/{hashtag}/"

    run_input = {
        "directUrls": [hashtag_url],
        "resultsLimit": TOP_K_POSTS
    }

    run = client.actor("apify/instagram-scraper").call(run_input=run_input)

    dataset = client.dataset(run["defaultDatasetId"])

    for item in dataset.iterate_items():

        username = item.get("ownerUsername")

        if username:
            usernames.add(username)

# save to csv
with open(OUTPUT_FILE, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["username"])

    for u in sorted(usernames):
        writer.writerow([u])

print(f"Saved {len(usernames)} influencers to {OUTPUT_FILE}")
# Out:
# Searching #fitnessworkout
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> Status: RUNNING, Message:
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:20.838Z ACTOR: Pulling container image of build GJs0yFKKFf9gQ7nsI from registry.
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:20.839Z ACTOR: Creating container.
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:20.874Z ACTOR: Starting container.
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:20.876Z ACTOR: Running under "LIMITED_PERMISSIONS" permission level.
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:21.481Z INFO  System info {"apifyVersion":"3.6.0","apifyClientVersion":"2.22.2","crawleeVersion":"3.16.0","osType":"Linux","nodeVersion":"v22.22.0"}
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:21.605Z INFO  Results Limit [object Object], ACTOR_MAX_PAID_DATASET_ITEMS
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:21.610Z INFO  [Status message]: Starting the scraper with 1 direct URL(s)
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> Status: RUNNING, Message: Starting the crawler.
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:21.697Z INFO  CheerioCrawler: Starting the crawler.
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:24.749Z INFO  Scraped 12 results. 12/20 for https://www.instagram.com/explore/tags/fitnessworkout/
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:24.751Z INFO  Hashtag scraper is limited to one page for free users, finishing https://www.instagram.com/explore/tags/fitnessworkout/
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:24.836Z INFO  CheerioCrawler: All requests from the queue have been processed, the crawler will shut down.
# [apify.instagram-scraper runId:OA3RHP7l24puZhfvm] -> 2026-03-13T05:25:24.891Z INFO  CheerioCrawler: Final request statistics: {"requestsFinished":1,"requestsFailed":0,"retryHistogram":[1],"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:46.653Z ACTOR: Running under "LIMITED_PERMISSIONS" permission level.
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:47.295Z INFO  System info {"apifyVersion":"3.6.0","apifyClientVersion":"2.22.2","crawleeVersion":"3.16.0","osType":"Linux","nodeVersion":"v22.22.0"}
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:47.433Z INFO  Results Limit [object Object], ACTOR_MAX_PAID_DATASET_ITEMS
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:47.437Z INFO  [Status message]: Starting the scraper with 1 direct URL(s)
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> Status: RUNNING, Message: Starting the crawler.
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:47.579Z INFO  CheerioCrawler: Starting the crawler.
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:52.314Z INFO  Scraped 20 results. 24/20 for https://www.instagram.com/explore/tags/fitnesscoach/
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:52.327Z INFO  Hashtag scraper is limited to one page for free users, finishing https://www.instagram.com/explore/tags/fitnesscoach/
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:52.358Z INFO  CheerioCrawler: All requests from the queue have been processed, the crawler will shut down.
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:52.432Z INFO  CheerioCrawler: Final request statistics: {"requestsFinished":1,"requestsFailed":0,"retryHistogram":[1],"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":4709,"requestsFinishedPerMinute":12,"requestsFailedPerMinute":0,"requestTotalDurationMillis":4709,"requestsTotal":1,"crawlerRuntimeMillis":4976}
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:52.442Z INFO  CheerioCrawler: Finished! Total 1 requests: 1 succeeded, 0 failed. {"terminal":true}
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> 2026-03-13T05:31:52.444Z INFO  [Status message]: Scraper finished
# [apify.instagram-scraper runId:AMaLnUp6NTb984QHY] -> Status: SUCCEEDED, Message: Finished! Total 1 requests: 1 succeeded, 0 failed.
# Saved 440 influencers to instagram_creators.csv

# %%
import csv
from googleapiclient.discovery import build

# Setup API
api_key = "AIzaSyATUINBiOlXRBLuzyq1HT6Hc2Hdd8giYpc"
youtube = build("youtube", "v3", developerKey=api_key)

# Load keywords
def load_keywords(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        return [line.strip() for line in f if line.strip()]

keywords = load_keywords("/content/fitness-keywords.txt")

output_file = "youtube_creators.csv"

headers = [
    "Channel ID",
    "Channel Title",
    "Published At",
    "Thumbnail URL",
    "Language",
    "Country",
    "Subscriber Count",
    "Video Count"
]

print(f"Loaded {len(keywords)} keywords")

# Step 1 — Collect channel IDs
channel_ids = set()

for keyword in keywords:
    print("Searching:", keyword)

    try:
        request = youtube.search().list(
            q=keyword,
            part="snippet",
            type="video",
            maxResults=50
        )

        response = request.execute()

        for item in response.get("items", []):
            channel_ids.add(item["snippet"]["channelId"])

    except Exception as e:
        print("Error:", e)

print(f"Collected {len(channel_ids)} unique channels")

# Step 2 — Fetch channel details in batches
def chunk_list(lst, size):
    for i in range(0, len(lst), size):
        yield lst[i:i + size]

channel_ids = list(channel_ids)

with open(output_file, "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(headers)

    for batch in chunk_list(channel_ids, 50):

        try:
            request = youtube.channels().list(
                part="snippet,statistics",
                id=",".join(batch)
            )

            response = request.execute()

            for item in response.get("items", []):

                snippet = item["snippet"]
                stats = item.get("statistics", {})

                writer.writerow([
                    item["id"],
                    snippet.get("title", ""),
                    snippet.get("publishedAt", ""),
                    snippet.get("thumbnails", {}).get("default", {}).get("url", ""),
                    snippet.get("defaultLanguage", ""),
                    snippet.get("country",""),
                    stats.get("subscriberCount", ""),
                    stats.get("videoCount", "")
                ])

        except Exception as e:
            print("Batch error:", e)

print("Extraction complete!")
# Out:
# Loaded 22 keywords
# Searching: fitness workout routine
# Searching: home workout routine
# Searching: gym workout routine
# Searching: full body workout
# Searching: fat loss workout
# Searching: muscle building workout
# Searching: bodyweight workout
# Searching: HIIT workout
# Searching: fitness trainer tips
# Searching: workout for beginners
# Searching: fitness diet plan
# Searching: healthy meal prep
# Searching: high protein recipes
# Searching: muscle gain diet
# Searching: fat loss diet
# Searching: fitness nutrition tips
# Searching: healthy breakfast recipes
# Searching: fitness meal prep
# Searching: high protein vegetarian recipes
# Searching: fitness lifestyle
# Searching: gym diet plan
# Searching: fitness daily routine
# Collected 397 unique channels
# Extraction complete!

# %%
import csv
import time
from googleapiclient.discovery import build

API_KEY = "AIzaSyDXYT0YflYEcmzkgTziBrwZoXSLwwR1V_s"

youtube = build("youtube", "v3", developerKey=API_KEY)

INPUT_FILE = "/content/youtube_creators.csv"
OUTPUT_FILE = "youtube_videos.csv"

MAX_VIDEOS=30
# --------------------------------
# Load channel IDs from CSV
# --------------------------------
def load_channel_ids(file_path):

    channel_ids = []

    with open(file_path, "r", encoding="utf-8") as f:
        reader = csv.DictReader(f)

        for row in reader:
            channel_ids.append(row["Channel ID"])

    return channel_ids


# --------------------------------
# Get uploads playlist for channel
# --------------------------------
def get_upload_playlist(channel_id):

    request = youtube.channels().list(
        part="contentDetails",
        id=channel_id
    )

    response = request.execute()

    items = response.get("items", [])

    if not items:
        return None

    return items[0]["contentDetails"]["relatedPlaylists"]["uploads"]


# --------------------------------
# Get video IDs from playlist
# --------------------------------
def get_video_ids(playlist_id):

    video_ids = []
    next_page = None

    while len(video_ids)<MAX_VIDEOS:

        request = youtube.playlistItems().list(
            part="contentDetails",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page
        )

        response = request.execute()

        for item in response.get("items", []):
            video_ids.append(item["contentDetails"]["videoId"])
            if len(video_ids)>=MAX_VIDEOS:
              break
        next_page = response.get("nextPageToken")

        if not next_page:
            break

    return video_ids[:MAX_VIDEOS]


# --------------------------------
# Fetch video metadata in batches
# --------------------------------

def get_video_metadata(video_ids):

    request = youtube.videos().list(
        part="snippet",
        id=",".join(video_ids)
    )

    response = request.execute()
    return response["items"]


with open(INPUT_FILE, "r", encoding="utf-8") as f:
    reader = csv.reader(f)
    next(reader)
    channels = [row[0] for row in reader]

print("Channels loaded:", len(channels))

with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as f:

    writer = csv.writer(f)

    writer.writerow([
        "video_id",
        "channel_id",
        "title",
        "description",
        "tags",
        "language"
    ])

    for channel_id in channels:

        try:
            playlist_id = get_upload_playlist(channel_id)

            if not playlist_id:
                continue

            video_ids = get_video_ids(playlist_id)

            videos = get_video_metadata(video_ids)

            for video in videos:

                snippet = video["snippet"]

                video_id = video["id"]
                title = snippet.get("title", "")
                description = snippet.get("description", "")
                tags = ",".join(snippet.get("tags", []))
                language = snippet.get("defaultLanguage", "")

                writer.writerow([
                    video_id,
                    channel_id,
                    title,
                    description,
                    tags,
                    language
                ])

        except Exception as e:
            print("Error for channel:", channel_id, e)



print("Video extraction complete.")
# Out:
# Channels loaded: 397
# Video extraction complete.

# %%
import csv
import datetime
from googleapiclient.discovery import build

API_KEY = "AIzaSyDXYT0YflYEcmzkgTziBrwZoXSLwwR1V_s"

INPUT_FILE = "/content/youtube_videos-2.csv"
OUTPUT_FILE = "youtube_video_metrics.csv"

# Build YouTube API client
youtube = build("youtube", "v3", developerKey=API_KEY)

def read_video_ids(file_path):
    video_ids = []
    with open(file_path, "r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            video_ids.append(row["video_id"])
    return video_ids


def chunks(lst, n):
    """Yield successive n-sized chunks"""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]


def fetch_metrics(video_ids):
    metrics = []
    collected_at = datetime.datetime.utcnow().isoformat()

    for batch in chunks(video_ids, 50):  # API allows 50 IDs per request
        request = youtube.videos().list(
            part="statistics",
            id=",".join(batch)
        )

        response = request.execute()

        for item in response["items"]:
            stats = item["statistics"]

            metrics.append({
                "video_id": item["id"],
                "collected_at": collected_at,
                "views": stats.get("viewCount", 0),
                "likes": stats.get("likeCount", 0),
                "comment_count": stats.get("commentCount", 0)
            })

    return metrics


def write_metrics(metrics, file_path):
    fieldnames = [
        "video_id",
        "collected_at",
        "views",
        "likes",
        "comment_count"
    ]

    with open(file_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(metrics)


def main():
    video_ids = read_video_ids(INPUT_FILE)
    metrics = fetch_metrics(video_ids)
    write_metrics(metrics, OUTPUT_FILE)
    print(f"Collected metrics for {len(metrics)} videos.")


if __name__ == "__main__":
    main()
# Out:
# /tmp/ipykernel_262/80257623.py:30: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   collected_at = datetime.datetime.utcnow().isoformat()
# Collected metrics for 11824 videos.

# %%
import csv
import os
import subprocess
from googleapiclient.discovery import build

API_KEY = "AIzaSyDXYT0YflYEcmzkgTziBrwZoXSLwwR1V_s"

INPUT_FILE = "/content/youtube_videos-2.csv"
OUTPUT_FILE = "video_assets.csv"
AUDIO_DIR = "audio"

os.makedirs(AUDIO_DIR, exist_ok=True)

youtube = build("youtube", "v3", developerKey=API_KEY)


def chunk_list(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i+n]


def read_video_ids():
    with open(INPUT_FILE, "r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        return [row["video_id"] for row in reader]


def fetch_thumbnails(video_ids):
    thumbnails = {}

    for batch in chunk_list(video_ids, 50):
        request = youtube.videos().list(
            part="snippet",
            id=",".join(batch)
        )

        response = request.execute()

        for item in response["items"]:
            vid = item["id"]

            thumbs = item["snippet"]["thumbnails"]

            if "maxres" in thumbs:
                url = thumbs["maxres"]["url"]
            elif "high" in thumbs:
                url = thumbs["high"]["url"]
            else:
                url = list(thumbs.values())[0]["url"]

            thumbnails[vid] = url

    return thumbnails


def extract_audio_and_caption(video_id):
    url = f"https://www.youtube.com/watch?v={video_id}"

    audio_path = os.path.join(AUDIO_DIR, f"{video_id}.mp3")
    caption_text = ""

    try:
        # download audio
        subprocess.run([
            "yt-dlp",
            "-x",
            "--audio-format", "mp3",
            "-o", f"{AUDIO_DIR}/{video_id}.%(ext)s",
            url
        ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        # download captions (auto if needed)
        subprocess.run([
            "yt-dlp",
            "--skip-download",
            "--write-auto-subs",
            "--sub-format", "vtt",
            "-o", f"{AUDIO_DIR}/{video_id}",
            url
        ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        # read caption file
        caption_file = f"{AUDIO_DIR}/{video_id}.en.vtt"

        if os.path.exists(caption_file):
            with open(caption_file, "r", encoding="utf-8") as f:
                caption_text = f.read().replace("\n", " ")

    except Exception:
        pass

    if not os.path.exists(audio_path):
        audio_path = ""

    return caption_text, audio_path


def main():

    video_ids = read_video_ids()

    thumbnails = fetch_thumbnails(video_ids)

    with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["video_id", "thumbnail_url", "caption_text", "audio_path"])

        for vid in video_ids:

            thumb = thumbnails.get(vid, "")

            caption, audio = extract_audio_and_caption(vid)

            writer.writerow([vid, thumb, caption, audio])

            print("processed:", vid)


if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# processed: caEwehdXoak
# processed: 7x9hR94LlAE
# processed: qKL054_UJbs
# processed: hk0DguGQMJc
# processed: ZT_nvd0ROBc
# processed: uQ01Y_goUXg
# processed: EKNBhJXmQf4
# processed: 3h0fP5VTrLY
# processed: q5XVFQN-yQI
# processed: pALhIhWOrXw
# processed: nuLRyPudALI
# processed: GIYhSFwK4c4
# processed: 9hqb5Wa1PH4
# processed: YFsBJFCRnYI
# processed: 06s-cVE3nvc
# processed: k8Ybm8Dcc-A
# processed: I09uF4SdCeA
# processed: Dn8cz8Q9M2A
# processed: dJxJ4AccIX4
# processed: HDz_sM8lv6g
# processed: VsNmyKi2EVA
# processed: ie2BNhCN6Do
# processed: 8HgTn-g1nNM
# processed: c8_QBf4cZA0
# processed: CNdtNJo_hiM
# processed: UfikVE1WVDY
# processed: xuphoTP8c90
# processed: sI_4oAoJpfI
# processed: WVSo45sUpoA
# processed: Lae8GI9Oq4Y
# processed: SR0x-de80iU
# processed: D1cK8Cxygog
# processed: A4VNEWi0R3w
# processed: Dnjp1ugxLtc
# processed: pDTfD5WKGNk
# processed: F-VRVXBW2U4
# processed: oCI6b9j6mvw
# processed: AUuy4PHnMO8
# processed: XNXWC4OKafY
# processed: egHeKREmLwE
# processed: INz6RrG4C9g
# processed: jrKOWqPySEo
# processed: wcG6f71eEn4
# processed: 4qSA3X2GeMo
# processed: k0B7VB03NeY
# processed: E-1J_0AxFeI
# processed: 2BrF0NW8ju8
# processed: nmZxtLyjF-g
# processed: _Uvo6blEjTY
# processed: sUtsctVFydw
# processed: zPr-BWYejQw
# processed: 4OIBsjihcV4
# processed: Xe2in8RPf-g
# processed: kt0vI11i8OU
# processed: 0x8S68pbmVg
# processed: 8nhPrduZ5nk
# processed: BINaFtw7jGY
# processed: IJ4MpNKgxZ0
# processed: fd2M9Wk1PME
# processed: Te8eH6eWR2I
# processed: vvSw5p1sWh4
# processed: ZiiKrwCFYVU
# processed: mQFnMlZlsGc
# processed: s1uNIMcYssM
# processed: y0D4dqCbYdw
# processed: aymO1VeOs4o
# processed: GWVybG0FcwM
# processed: wZDrbUT5rUQ
# processed: 3HrD0PGWXRM
# processed: GJKx2bdZjg8
# processed: 6oazWF_HTQ4
# processed: WGC0zVusXho
# processed: p_IeDggK0JQ
# processed: baJ_eH4x8DM
# processed: A_IkmKRVens
# processed: 3l1BY7N26kE
# processed: RMANVXAB9zk
# processed: CPnfe7FsZI8
# processed: UNunFnWw7eI
# processed: k976MqmXYPc
# processed: WUcLgfs1gUE
# processed: tMy5SdIpzeU
# processed: FgSsBh9PRGc
# processed: Ft9IemSgcb0
# processed: GK6jaKbaHag
# processed: z8qhMULKVQo
# processed: HsEnIxg0Sig
# processed: FxRP7eC8mK8
# processed: 0jm_thT_WH4
# processed: W-ZWq1iC1Fg
# processed: yOq61T2p4cg
# processed: TdFMDgUhsY0
# processed: LCp6tufo6iM
# processed: eUNVjJaoi-I
# processed: TmIvGpYjHe4
# processed: yFts9yxadZk
# processed: q6k4-WWxE1E
# processed: pIU9xZhZjvQ
# processed: arQOk_slWLU
# processed: FHT-Pvnv5Vw
# processed: y_0PjoDRBAA
# processed: H6xbn794KPY
# processed: ILqsCL7ZnI0
# processed: MN-xac_VJzg
# processed: aIIIR_SJtCA
# processed: VSrVNYaLiOk
# processed: BRJc2AS1VpY
# processed: Gy7uiuoOlEM
# processed: iDZSJf46N6w
# processed: SC2FSEwTD7c
# processed: sdaImBHvIjo
# processed: aQJGFf9Y4Bo
# processed: pcGQHBorhag
# processed: UZ3U0X5fb1Y
# processed: -kWoqHoLJWE
# processed: bUvVm_ELEvQ
# processed: XJs9hkPs-Go
# processed: XpGGKnShbEc
# processed: cA11MYXhBfI
# processed: 155Nb8rjYLw
# processed: ef2dgRoTKzI
# processed: 4fhNMX0h1zM
# processed: d40cwcOsJTo
# processed: UpWTwUUO7w4
# processed: t1uZG3OhH4c
# processed: _TVrcXtiuYI
# processed: uDpz6B0cvto
# processed: dCpFH8v_taQ
# processed: IRt1Aadbe1A
# processed: 73v1C8JkdaY
# processed: j18JtsD_gw8
# processed: OyWiG0wVrto
# processed: Df2T_iPEwvE
# processed: d0dxbEdmQE0
# processed: t2L7TwbnNdE
# processed: E7iAwEZOACg
# processed: 98phi7XF5dU
# processed: GZRETXug98o
# processed: 3_3FVwujbv8
# processed: AN5g92-OXeo
# processed: DltAzzQWY5Y
# processed: 3ulcBsF4z8A
# processed: hS7BX7UHdV8
# processed: myvoFP_XHno
# processed: UbLLDz0zJ1I
# processed: c_81Th0StrI
# processed: epCHrhcEKpI
# processed: GZwTKL-ejU4
# processed: Du8qx_PZdm0
# processed: gwMYQFzFZ0w
# processed: TFaOW42RmiM
# processed: eK9AilKvGYM
# processed: z5fP56B1FxM
# processed: 5miQTnBhGBo
# processed: p4VwBKMkEMY
# processed: 9QwKOKhtm-s
# processed: RMf1Wv_HcEM
# processed: NN0d4Nydqfk
# processed: yopD2vkf3AA
# processed: gG8DPOf7YYY
# processed: Likfq2MnW_M
# processed: xpMh3NfmMOA
# processed: H_G3MPQxneQ
# processed: kPMPy1faxdw
# processed: hggO6pI3VVs
# processed: 0gV4BD_o-6k
# processed: 16x41aUamUE
# processed: qMTWFv-AIE8
# processed: LTxsoQGEV6Q
# processed: 6g3jo2l5HIs
# processed: ulk5sABQV-o
# processed: huTUgEVTx2g
# processed: _888SIAr7D0
# processed: tp0GCFf0ATk
# processed: VgKigUWvp20
# processed: DLoQIFBcYCE
# processed: 629YKHznCsU
# processed: 6ane1pG9bvY
# processed: 7qQbWWknup4
# processed: Yk-IgQBeB-I
# processed: KpDIwWEwYTk
# processed: 90thNj2gqRs
# processed: lPBlqts38T8
# processed: w0TB8aQVoCY
# processed: pWRM7vK4Eg8
# processed: IMT6yZam8Uw
# processed: 20_6qO5FObU
# processed: BLWnQMkOOYA
# processed: xFJ48Ul7qfo
# processed: pWe5tuRRWtc
# processed: 0vk51qBYKp8
# processed: oXaqKIQ4--M
# processed: HqLVYDhVsN0
# processed: oAyk2Oh_Nes
# processed: ej3AiVBZxmI
# processed: 7S4edM9c9pI
# processed: -v8HuOwIBsM
# processed: twsbaItR5N4
# processed: v9k_TAdu8r8
# processed: pxmltdRTEz8
# processed: gy3hTKC7Pts
# processed: ia4oM8Nszq4
# processed: ULcF8zKx8JE
# processed: MqonYKxZkPo
# processed: v93MmzLIBGo
# processed: Z7NuqN9Neag
# processed: p3kkbV71CdQ
# processed: 3jTHXl3-2Qk
# processed: jBQ9HGpPr2o
# processed: Ijz0h8XWK-4
# processed: JmbGxERKxDk
# processed: T692uOt4yrU
# processed: hh39xOrSgRc
# processed: rI-lhhX2Y5A
# processed: SdAhncYy-mU
# processed: wNcYCfqaTAw
# processed: 2H0J7HfEmdU
# processed: svHCFK-AScA
# processed: ZOOJ9ANG68Q
# processed: 8_HCz_MVX1I
# processed: BU7rWFcIpHk
# processed: RH90sMnK1OU
# processed: LYpl794zjGk
# processed: MLL1CgiCgdI
# processed: 2NnrNYcw2Wg
# processed: R8X-gXpe9C0
# processed: kHXBL5BTIus
# processed: 2rWlgFDpebY
# processed: OcJ_BRphhl4
# processed: 9LnuSq9D49w
# processed: 7Zwq8C3cfyk
# processed: F8iAB5raMO8
# processed: DUyMIsbhXXs
# processed: egxa3qaYwNA
# processed: Z9coUrfcI0s
# processed: 5c1R1zPceyM
# processed: _TnNZcqurCw
# processed: crcHvDs-YoU
# processed: YRu4bS1CzVs
# processed: Aabfoy8HbIc
# processed: MbmBCj711U8
# processed: Ag7Dui9Plys
# processed: SPC37KpFpTU
# processed: gLz05PhtlPg
# processed: -iV1hh4vPEc
# processed: mCahca4wK-4
# processed: wAM5GMfrBSo
# processed: 4hHtTUop5JU
# processed: ILlTcna0hpE
# processed: zHXfXaofaTk
# processed: LGsS-T-cSEc
# processed: KKBZeZszOOM
# processed: ZkzdgjtUyT8
# processed: lEHqcWy_2_w
# processed: yBj9H-El4Fc
# processed: hu-mS4_rAKA
# processed: Pff62I_7Woo
# processed: wrbj6pmQ6XE
# processed: mjepkZLSWaM
# processed: 883MTiuKe7Y
# processed: JYZK_bQstBs
# processed: v-oX90oHNp0
# processed: yNvWx49cNI8
# processed: a3SDpFq8_Fs
# processed: NRSpz58uA6o
# processed: FauMIaGTL5Q
# processed: q-QwZoPBW6s
# processed: 8Ltdopk22_4
# processed: xALlu0B3k6Y
# processed: DOQ0OmKHy60
# processed: h-fBj_-tD6c
# processed: a0PPs8klSo4
# processed: nMHNgk5J5j4
# processed: natw5kzRq08
# processed: 80_W9ltWLXI
# processed: LKNUV8dlGyQ
# processed: kstpYB3gyhI
# processed: OWpb2QITvdU
# processed: lFo22duwfk0
# processed: S254DRdGfyE
# processed: 3Q0qhY8IKnA
# processed: tm-j1tIHtqw
# processed: v2k5at9PwpU
# processed: dvD-HAQKJBQ
# processed: wbmBYiXXEFg
# processed: UJTPboTPzUY
# processed: PPiol4vVBeQ
# processed: HrvXB3EvCsg
# processed: 8MjdFmbSzdE
# processed: q3snVI-vyB0
# processed: DbSl49ZTwb4
# processed: gwDoORn0lZc
# processed: yOdxyAqW-kU
# processed: IHYZLyS4YAc
# processed: VoU27-mCSpM
# processed: PGmUoJFrH9Y
# processed: DPR_E4yxy9A
# processed: T7z3Mb_lf4I
# processed: -e6lIQ58ASw
# processed: XJprg48Kb1k
# processed: rHSnnvVLh4Y
# processed: Y83D2u5cCDk
# processed: PJ54HCfpbAs
# processed: kuTleMoyCkE
# processed: 7XWtziJSDqg
# processed: 6sfaunirDTg
# processed: wB0vlEtu0_E
# processed: YmVErIE_0Lk
# processed: r8wnjFwH7TU
# processed: ge0Ba3nhn00
# processed: WrB7QUpEa4A
# processed: 7VZWbR0xdu8
# processed: Hx5YJ0tj3rc
# processed: FL99GI6auqE
# processed: hTr_ntXKcZ4
# processed: cvAgxll1AlM
# processed: IbFTAj_NegA
# processed: vmJqvSyAbWM
# processed: HZJmYRbpd9w
# processed: hYqX2Y-gaSA
# processed: O1qcPMaGd4M
# processed: ufggGhol_3c
# processed: dqhw2f3OAVk
# processed: ApQrJGyr9cE
# processed: NdXT0SaArpA
# processed: E44Iu3HqHOo
# processed: E0XeAF1mSUA
# processed: vU7jXQ2ZqAM
# processed: Rtc_1OxayzI
# processed: nPRXDOZoNBM
# processed: 55N8M3KlI9g
# processed: UTW48BfUG1A
# processed: 6k8RnCz8PvU
# processed: sRKTlaBEL9I
# processed: 0CAxh6hbADo
# processed: Bn_1vQUkWg8
# processed: 6jG1X6L5W3A
# processed: XtmHYtg9k4s
# processed: 4bfvjVQMDZA
# processed: oJVLUAsG-dc
# processed: dx51mXSjSec
# processed: lRlwWx1XjGk
# processed: MsxFHaUY-kw
# processed: ql7lQFVhJQY
# processed: jHF-TRKJuZ0
# processed: 1esw42W08fQ
# processed: Tfqn0H4U_Ig
# processed: 85hlciNrpeE
# processed: rx0nl4cwe1M
# processed: 0RDNES2rEeU
# processed: UFjmSnLrjhM
# processed: MOpnTy7fFzw
# processed: uXhMWfO4PZs
# processed: 0buAmluzHHw
# processed: PwV-8-POfls
# processed: YZemQLyK8Z8
# processed: fcgwGOdCznU
# processed: 6w84kkx9nt8
# processed: GGLyYAqnN8w
# processed: 8u2fFOeclKc
# processed: EQiYmSE01uE
# processed: P75-wCesJf4
# processed: QVitQGb2pUM
# processed: DNQ3T9p9yqk
# processed: 9rfA8PQL6GQ
# processed: 15qnKpEspBE
# processed: R9dAxagTNt0
# processed: DnxRTlTnReA
# processed: ezU2WOb8b-Q
# processed: FVLiFfmmsKw
# processed: RBECAc5VWeU
# processed: 2yOaDbFD168
# processed: SO3csT7gNvY
# processed: h6UjqwrSaE8
# processed: KtSkNsJVEUw
# processed: ooy86w3mUto
# processed: IgScUW-hXNY
# processed: EcmZArwBVRM
# processed: h0Cc0NiBNKo
# processed: wR7vRyxtvJY
# processed: zzrPv4JQuw0
# processed: 80wGuQY9BDE
# processed: Nj1Irhs0nlA
# processed: aDZgRvoFzB0
# processed: DaUqRelgf1U
# processed: _1R-IvvXE9o
# processed: hhAsSHjr6S0
# processed: lMndiKQBI1I
# processed: hqEvIKdD8MI
# processed: 3QO5UmU_Av8
# processed: OkMVuQfXCPE
# processed: kRnveCejT-s
# processed: _qpQDQyTHeU
# processed: bYlaqZkndkc
# processed: uDKesXW6RRs
# processed: Sx_-raU0JUU
# processed: fVnRSh_4obY
# processed: q6pwp5BvKFw
# processed: rpKPjAmi1gs
# processed: RYnuJeM6jzk
# processed: kDVA-m3Zk7E
# processed: s7EKftOqDCc
# processed: OCVDaShUOT8
# processed: iGJk5aPQBoM
# processed: lmfPuJ_3lds
# processed: B1S553i9hsY
# processed: HH7qViXeSx4
# processed: rCaqSlAqVXQ
# processed: 57AQfieTXU0
# processed: 18IlS2XpHo8
# processed: iL_O3-13X8k
# processed: 5ncluqpKlm0
# processed: HMTuxgAD-x0
# processed: cjb9JvopNSI
# processed: 8gvfxLSK7k0
# processed: xy4_12ge1jA
# processed: wKOkTSlC69Y
# processed: EvH1khoQ9HU
# processed: Y1gVTTDeWOM
# processed: bXs-mvgfnfM
# processed: iieBnGL8Mpc
# processed: 6crxl1HN1Jo
# processed: dPhDIMJ5BH4
# processed: BqbPOHS3RWg
# processed: 4lZaXkPsAzQ
# processed: WwQdtPjDf0E
# processed: DCygWKOdZBw
# processed: DhKVDAV1O_w
# processed: eEhfkP1xEsI
# processed: RxgjAgEmZdc
# processed: 2QBk-8DSW0I
# processed: ZAeE_x01XFI
# processed: bkRvrUpRi60
# processed: 4QuHsJ6_ZBM
# processed: k5JGRTFxvjo
# processed: PXD3HW5CPL0
# processed: pwubl_vUtJY
# processed: 9doUMvM6zSE
# processed: pd4FL6wYEfY
# processed: 0bFz23tszvE
# processed: V1Di4bIuiLw
# processed: S_-sSmIKy1c
# processed: ZvqHtzUqqHA
# processed: lXTH0AkyHFo
# processed: KayOzuZK7jg
# processed: fOFy2DLN4h4
# processed: fe60wmWfDUI
# processed: wkwHj4uj8XA
# processed: jbS1H6Bnz2A
# processed: JnujuRoL-z8
# processed: _nncMKq9ACs
# processed: F-2rsso1SO8
# processed: Hx6va9Swezk
# processed: KRBT5pC_QUs
# processed: MAG4596RskA
# processed: dv0WyQsYlw0
# processed: btMvY46Sch8
# processed: vkTkhupAJTs
# processed: P5qv4JvXulw
# processed: MxA-yis6JTk
# processed: UX6IuxLluPg
# processed: LVOQnyS_mVw
# processed: ljlCiue9INA
# processed: sQj8T0UxSEQ
# processed: FnNGJzgA0nI
# processed: zDzjaTUe9W8
# processed: 1V7BK-fwLB0
# processed: i5E0OMe8bM0
# processed: TUdvoVj1xzs
# processed: LwA8KK6RaLE
# processed: W7_tiCbjn7E
# processed: jlh8ZWGlD_Y
# processed: P34f_Rdsi-I
# processed: DH8_fWQUu1w
# processed: UHrCKfHn7vY
# processed: bUrp42VLMOQ
# processed: kCtl_Cyi91M
# processed: 6EAfd7DvkGg
# processed: qHHBuGRsT0U
# processed: MmHyeGa4W0U
# processed: BOfACK7wzQo
# processed: Dg5r56Uq2zk
# processed: Pl1OmaeAXBw
# processed: kPyGEhISQn8
# processed: J751fTqibfE
# processed: 2MfnvPDPkLg
# processed: STEsjt-xqfk
# processed: b9ukzMipfqU
# processed: _Bc-y0rVUOI
# processed: aoiRlv-UbPs
# processed: 1jtdihxNC78
# processed: Uj4APC1iNo4
# processed: NavATZieSw4
# processed: 4Pi8AlvrWGk
# processed: Me1x3rsCc6o
# processed: skrMLMsR6z4
# processed: KIUdWk2WRWY
# processed: 9KLwFsHmTkU
# processed: XHacIVmS8Rs
# processed: TP7_3kSC6P0
# processed: nSzOKA7hsMw
# processed: Vm7h_KPvmi0
# processed: xQUtSd8x3Xo
# processed: whlh-GoisSA
# processed: 6OLAZgOHL_A
# processed: __aH9Rn6ELs
# processed: 3zDuBKZPmmM
# processed: LYQ0QyyUJPw
# processed: Ct8U_ehUYjQ
# processed: VwZlUHjG7JI
# processed: 0alFlUMdRuo
# processed: EFLLrynfaZ8
# processed: TUCUYnn9XGA
# processed: 6A8HyztEigk
# processed: vj33KZ-rrwc
# processed: Qg40o_Z3k44
# processed: Ns7eWN1nx3M
# processed: 6Rcx1BMMVeU
# processed: 52-1CPHVqIY
# processed: yUNUpJl7mi8
# processed: 0qEUeyDiCko
# processed: O6euiNEoJPQ
# processed: yd9FRrgyGCg
# processed: hDj6RQcaD3M
# processed: X4taKVqqsnA
# processed: tnINI1SMN7g
# processed: CBZYDyNLxWQ
# processed: FRK8PYQRnGM
# processed: q5BLZ3hgsd8
# processed: RVqTuzb64uc
# processed: 2bZyok5XHyg
# processed: BGAdu6lqZJk
# processed: -JTfLB_H1xM
# processed: hyonzO9TxEQ
# processed: av1_SBH7YBw
# processed: N8P36kYD7xQ
# processed: l_mCAO7L5vw
# processed: Jwoiu3ehHmg
# processed: ZXf_56sjKb8
# processed: pra1pmmPSag
# processed: V3c90PPsd9o
# processed: iLvuBQDuGdg
# processed: WKzIjTa-vig
# processed: 8g3Ntfx8Vt0
# processed: IoJVDThQZ3o
# processed: -QJS9aLoZ3Q
# processed: rCCX5XbaGD4
# processed: HVPxdXE5zSE
# processed: fP2K7YPRgZo
# processed: 5eZBwJpYqf4
# processed: CcBSuE538ko
# processed: RPgoC4umYJQ
# processed: 0S8ZbnnBNFc
# processed: cNQuVhjxI1I
# processed: eLcq30YWAmQ
# processed: nwI2ZNQAaFc
# processed: ToDfLMuYxm0
# processed: iBCv189hccs
# processed: 8YuhchxBWns
# processed: W6y8T8_09Gc
# processed: RSYbijiKQWI
# processed: t9qTgCRRwGk
# processed: WUqnX4h_cIE
# processed: 08w_HY_jp9w
# processed: 0QvI7CFUDsw
# processed: 3qVF7Mp5hqc
# processed: l4XsPfTfiWc
# processed: vK4b3loKB3M
# processed: eJNPbtvgY0k
# processed: QeAVbMi02cQ
# processed: 33oIfbCy5B4
# processed: mI4G2VbfELA
# processed: xQK0tJi9YgU
# processed: ZImAXhJBa6w
# processed: LXVu2WL14sQ
# processed: VlupWT71KME
# processed: CrrcO69vl8o
# processed: vLNvF5VHzZM
# processed: yXAMzIoyMys
# processed: KPGPTKcdNwg
# processed: l-C_IcK539o
# processed: ZUAP_AQQSpw
# processed: BUPGGUB1Qps
# processed: H4mFkKySNso
# processed: AojgNgzaMFo
# processed: DJYdOeAroSc
# processed: Xw9htff5tNQ
# processed: lQVLZajjRl0
# processed: jSDwIKnww80
# processed: 461GS7JGH2g
# processed: PSm2oH4SAPo
# processed: g-FFzvpPVJU
# processed: pLLcJpw-Dm0
# processed: 0D7qno3MlZI
# processed: 1yt5Vp1k1l4
# processed: 5EPEQ57dsk0
# processed: Nf-wewNjnWU
# processed: XhJ2FbCQQ7U
# processed: 44AQabZfBAI
# processed: Jdr66QkurN0
# processed: m91d7V4CH1o
# processed: e40kACHCERQ
# processed: 93Y6N3pFfpU
# processed: 7mvWoeYwn1w
# processed: aHWwUv-gVT8
# processed: 0p8FGKjnGoQ
# processed: 3JZ6-_KidPM
# processed: OA0fHXZHTlY
# processed: FRglg3PKgO8
# processed: wwKXei1Vknc
# processed: Z9G6M0LmTVk
# processed: gI0lFSDPrvQ
# processed: 668z4NU4Kgs
# processed: B6nEd1vicOk
# processed: KPhR6Ujzb_g
# processed: GWueMjpycIk
# processed: XlZOyZZXhaU
# processed: Kx1znn-bzx8
# processed: RE-Zh48gMUQ
# processed: giG499rMmy4
# processed: 5rm8Q-mlqkE
# processed: 0RfJBTteKSo
# processed: HcH1g2DpG0Y
# processed: qtN9zY9_yiw
# processed: OI9lrWMssGk
# processed: 1ev5sKuepGY
# processed: FzgDeXbbrrs
# processed: q5Z4UZTqD6I
# processed: r71vCKSnmMQ
# processed: GCvcDnA70ak
# processed: ShrzfycLHJg
# processed: xk6DrO0NMIs
# processed: LZja2rNTInM
# processed: jnuadcfdx08
# processed: ZK-BNdlABbY
# processed: Heu8bzkuNIg
# processed: fqQOMJdBRSQ
# processed: Gc3RDATHDDo
# processed: Ig7zx_b4-lg
# processed: 8pP5zrRfttA
# processed: 9hwo1J8SrmM
# processed: F4X-qduMwwU
# processed: cj2Ts0g9gH0
# processed: w968UNTJ5P0
# processed: 8dpE9Y2oZNw
# processed: Yz39mFs4STg
# processed: YlUl1CxB2iA
# processed: Jgl63DGpukc
# processed: jFsb8BG6C2I
# processed: JAofq0C6abU
# processed: 7Jx9Zc4lTWc
# processed: 42CEVleS83I
# processed: GS1SpvnqMbY
# processed: 1XP6lNjlEvk
# processed: gozBJkrgGRQ
# processed: SRHm_LNcaxQ
# processed: -oXylkyO0qE
# processed: fpJuI_XZjzM
# processed: BQ8T6Y9aUqc
# processed: 9nDl9bTxcpc
# processed: ZuCowNFRD8k
# processed: sdXl6Q5pc9A
# processed: ga8wv9xrz3s
# processed: Tq-f9Rpo4j0
# processed: E_1pskHRq_g
# processed: G16KE8KDj6Y
# processed: 33-HzJwyd0k
# processed: 85ZmZzDwgUQ
# processed: 9XzR_AaP38c
# processed: Jz9g6t3cgAA
# processed: jXRof8A6Id0
# processed: uRukg0LGSnk
# processed: aLpq5xkDNmU
# processed: 742VjZrPt1Y
# processed: 5u06iD7cVjE
# processed: bkdmqjIeJp0
# processed: hk7clNvRNcc
# processed: NzqannxgGGo
# processed: wlWSNbyiglk
# processed: ce_C_EFiS-s
# processed: Mpb8J0ujTc8
# processed: vdp4gTzmjWU
# processed: HePRkMWVrsw
# processed: qBm5L9NI-KY
# processed: -M-aT0qRd38
# processed: mJUpAztjfe0
# processed: FQNRDDDzR8A
# processed: 5jqi1o05F-o
# processed: n0GFfsp6N9Y
# processed: SvYrkIZz5n4
# processed: jJ6CJ958dos
# processed: A1XfIxXGYgs
# processed: 0b9F6P4dpKY
# processed: XFrH7xfEmZU
# processed: NVnYbj6MEKA
# processed: x2AyRUQSNDQ
# processed: BCsNOPhlQpw
# processed: uNgMeS-4YNE
# processed: TpLY6BJXNPw
# processed: _7qLwjEXBuA
# processed: 5Nf0DoqvB1M
# processed: T7SXLfbznlI
# processed: L9x4mJtBMVM
# processed: RGptpydZBFg
# processed: 6ETxOR6Ex9E
# processed: EFDQmFO1I84
# processed: KKVH3F0voos
# processed: mEoQgGUOT8o
# processed: Ve080cHinfU
# processed: bKc3XE5a1wY
# processed: E4po2II4IXs
# processed: J1CyG604qAQ
# processed: ywoba-70Jsg
# processed: YPG571H809o
# processed: Ks_Y5AqztKc
# processed: qtSIbIzQHXU
# processed: QSpWWQ3IYT4
# processed: qs_aw5nSs6o
# processed: tfSJlFqWthA
# processed: 1jqIq_EA8uM
# processed: -XwU6KVb1Cs
# processed: m3t-NO6NT7Y
# processed: EPJWvv6vq0o
# processed: o2Gtqqt-14o
# processed: EylkRs4f-Kk
# processed: RmWLZkYUMKM
# processed: z7yQmUBUMYY
# processed: sljm3ubLyE0
# processed: j_QBMiXTz3w
# processed: 1W6M3YCo2Zw
# processed: GeTx5WbfO9Q
# processed: oMNBIqPDrrM
# processed: 5j5TQgtaAbU
# processed: wpWdzCsXvlA
# processed: 4IzS2aV6i-Q
# processed: Mhe-ne2BEiY
# processed: 9EZe0Ob-_tw
# processed: 6kRH3tte538
# processed: DVj1Y1R7HWs
# processed: tquNeRWL-sQ
# processed: eYzBOaRQXqs
# processed: Xv4MCoOyULM
# processed: ZHLjMmqJ-D0
# processed: 77rp1mH3YIY
# processed: Wq2tCesGwmQ
# processed: cFwfVxxcxz4
# processed: 6k_v7o2M7wU
# processed: Ah2DrC4dWaA
# processed: nSBOqBPqEys
# processed: UvzZqT3xSU4
# processed: xLOlVGqRL0E
# processed: odB_CiQ4drE
# processed: TF1OTdplaxs
# processed: ecoTlTfqxlw
# processed: LE1V4xVF3cs
# processed: 4EzdTuDo2Us
# processed: F73Z19Ugo4Y
# processed: gLk8sL5wJis
# processed: VOpV7J72ViM
# processed: FgT7dG-rgWE
# processed: VVliFkyjs4k
# processed: AaCVXLMh2Wk
# processed: goRfmu0JtT0
# processed: UwZMzmHM1jk
# processed: qkgT1f0VAYg
# processed: xxfp_aVg35A
# processed: BQuGQXs62yU
# processed: dYQL87BotGw
# processed: u-Sv_cyqPrE
# processed: cZac_wirs8M
# processed: RGwKCKuUJlw
# processed: tOAsrvK-Hw8
# processed: pVKTPmYY3tU
# processed: wmJpZgvWyOE
# processed: uKd6HYhLtaw
# processed: tELdUR8cakA
# processed: ryM43zExcIE
# processed: O8cP_TGKS68
# processed: bvJp47i2d2c
# processed: R10RTMDs7fU
# processed: Vsx4R46S2ZU
# processed: Wt0KQV7Twyw
# processed: 1vzZtrFoW-o
# processed: J5FpofOK7V4
# processed: vZlSbqptNIg
# processed: ZXQ9Owkecqc
# processed: 6anNRjGWu8Q
# processed: FH7mWKpsnGs
# processed: iiOl98dZSR4
# processed: 036hjll6FNI
# processed: s4DejWWg4qQ
# processed: 03fOdV5Dbp8
# processed: gZKTPYc3-UA
# processed: qMJ70s8z6xk
# processed: FV4rBP8WwAw
# processed: Eb0cO3zy0fI
# processed: KFHw5eSBt6E
# processed: bm-XSGrVeW0
# processed: wP5AnmBLz0E
# processed: Ap_8XQ5h9gw
# processed: xkp3-ybrf2E
# processed: jS6flvVYcAw
# processed: mIThnLGlKhM
# processed: wFRjK2FOEqA
# processed: VsuFAETqGHQ
# processed: jcWGnphfAP8
# processed: g9USIw3hRT0
# processed: pn_CCGwwqk8
# processed: Mr5e80iC-GY
# processed: FJntCb_m3Cs
# processed: _wAx2IJgsTs
# processed: EH-f4u738Qo
# processed: eyLeS4G8KAA
# processed: yJvp_U_Cld0
# processed: xFsgftdNh-A
# processed: WFhXMuSIxNQ
# processed: BVC8DKLlhS4
# processed: CZvNuWQyQsg
# processed: Vvf4KhcauNc
# processed: j_oYm2q7RSs
# processed: GmA1l1FURTs
# processed: 1XlXNidYE9A
# processed: YEWzTlSpCPk
# processed: KJRkoH9JhKo
# processed: kfFFhtBbidI
# processed: bn3Ctp-Y88w
# processed: e6OagO2FGZ0
# processed: klZXwtRvEe0
# processed: ZjxQdXnXc9Q
# processed: 2-S30_92sGc
# processed: DPfWw9IM8NQ
# processed: uD0ktxyKUEU
# processed: mKfkcnVEwcU
# processed: OrpFukTHBvw
# processed: 7pOT6RMnhqc
# processed: 7tAOnmoUlOo
# processed: WY9xbEoz6xU
# processed: vXjhw5dtxXg
# processed: wy9pqUDMugA
# processed: 34ReNs8o5mc
# processed: d-8z7D5ZMo0
# processed: j8EGIsJHCyM
# processed: Qe8_NO1DVFg
# processed: xZsoEy9DjzM
# processed: 7EgTYt_ZTto
# processed: fyt4NHM0boA
# processed: ow0iumGEscg
# processed: 0zZ-oBAy724
# processed: fKS7bBOa-lE
# processed: J9TtT-DFKPw
# processed: itOKObaUfWI
# processed: hrb6vUVEFJE
# processed: bC16-Zq9opM
# processed: -4KpEmXqY60
# processed: kuNzeQE0aVw
# processed: kkKnzQC_sbM
# processed: Z95sMxgo32Y
# processed: RIu1gOhVwiI
# processed: ThnjUZnl_VQ
# processed: J4OxvhAgyno
# processed: f6XocpKEoH0
# processed: J5ueq7sx5UI
# processed: MUpECW6yflQ
# processed: IWcEvrRobaA
# processed: U_T1fJjlbrQ
# processed: gvqW_mkZ4EA
# processed: 5Fl0SV_EwNI
# processed: n7fNLDhToPM
# processed: W7QeTKYrD_I
# processed: oXSEfC9ZvaQ
# processed: J8ftXjDTQog
# processed: ceazzdiCokg
# processed: 5UFcou2WgZU
# processed: 7yB3f2UpJVU
# processed: GT4NNhRAqo8
# processed: w1_Ph0sI_Ng
# processed: SP82emiobgc
# processed: K0JpTs0mBOo
# processed: nmr7iKGUT7s
# processed: Hxzoc-3MoYw
# processed: d78OJerhPxs
# processed: OMF_FlNmLSI
# processed: ww6vetgeOjU
# processed: 0uaFmDeADb4
# processed: bwqvM19Nzg8
# processed: JBtc7oB46gY
# processed: h4OtTL7TDvA
# processed: 2rsyrVlZGP0
# processed: a1aWlzwRIM8
# processed: KzxQNK44Sq8
# processed: YKfty3vi5Ls
# processed: gu2OJBVbWQQ
# processed: 7vbJRy4WQVI
# processed: RN3c3Xhq-jo
# processed: WNjlvK1iUoE
# processed: DajELSBVpu0
# processed: duFdM2zAmYY
# processed: O9fM5wtmHc4
# processed: jiaXqlep9hc
# processed: PXxBdHqrkx0
# processed: 5usomyuKxkc
# processed: 0-OIMLZ0Wjs
# processed: Rb8H2w1fK-M
# processed: co3c8IBzMpg
# processed: 0kQebFPBHM0
# processed: ul923aZHBkg
# processed: B154RzKsQao
# processed: v1NN0dp72bE
# processed: ZWWwTodXKAA
# processed: UxPmW7BGs3g
# processed: Mou9Ltnamog
# processed: b7ZylOXpips
# processed: Md31TpVXZC8
# processed: ebOmDXz2fFE
# processed: nS-HE5ojMcM
# processed: sftgbWjNwVM
# processed: YuE-yGT0Fxk
# processed: CEvVi6bO5TU
# processed: K_sfooguTTc
# processed: bPIxQTyZp5s
# processed: BvCgawsFieo
# processed: Dn-pJ8NatUY
# processed: h8OdH1yDE74
# processed: vGBFHUyhCEk
# processed: ONSGkB7lt78
# processed: 7ETuOW8URNQ
# processed: FtHpQuJq_eA
# processed: G5Q3ylzS9mQ
# processed: Fdvew7FmmKU
# processed: mYDnA2HHanU
# processed: pkK9OhVURWY
# processed: 0ZfNlgY0gYU
# processed: BnQWy96CQxQ
# processed: W-SFM4Jzr8k
# processed: S8qfs4CuvMs
# processed: JdYz5Hmci8M
# processed: f-Qnh2I3QFM
# processed: tngNG3FvJrw
# processed: NMxnoaJOBwQ
# processed: -bu350sbyIw
# processed: 1pGd_PXXpc0
# processed: E9mjESQrWQg
# processed: Ov0UlUpmUwU
# processed: LG_Sh4ovcrs
# processed: Q3H1GapkApc
# processed: hBok4V4NtwU
# processed: QSZNFUpL_90
# processed: ZV6-a0uRBm0
# processed: QpylD1n2DH0
# processed: tsPgVI6QQ9E
# processed: Gm-4jft3wdw
# processed: 67fi8WSkOpo
# processed: GPvWPfTjVJ4
# processed: F-8_T8BsVjY
# processed: bctfV3v7W_8
# processed: DM9ojJX54M4
# processed: 7Q7zQ0i95pk
# processed: aNH3oH3Xk9c
# processed: 27rbjv4QkrQ
# processed: 3s0b6ncIioA
# processed: dE2xEubZHJw
# processed: jvQx2j4LVNE
# processed: eGHsDvXIXAI
# processed: KO2FRqXClAo
# processed: r8n2gAjGvAA
# processed: goHzdTNw8VA
# processed: IhU3c2Rrh8Y
# processed: ToWSi-CS-mQ
# processed: nCOcrLZB-i0
# processed: 7TTJLZf_Qg4
# processed: 46sB31OwPwU
# processed: OITXoRBf2KE
# processed: pfxrEfWCDP0
# processed: mKIWmc1X3uM
# processed: xBpbuRYJJaw
# processed: Ws4zkjcujHY
# processed: WqbWqgK3m3w
# processed: 4nPSW2uNCcs
# processed: VmdCgZ3HCmk
# processed: IymmX9uC1H4
# processed: r1mTJKmaiIw
# processed: ECiTBMKtoXg
# processed: DKBCBR0JtrA
# processed: 7iRayCuFxjA
# processed: ja-4HwUfAgE
# processed: P5euIOTAUGs
# processed: M-4-4j9Qtck
# processed: rioLp3zqQZ0
# processed: 4-DOGd_uddo
# processed: fWFJWOJP-3s
# processed: NQLq2KQQvgg
# processed: Y1AIKMNd3FI
# processed: 6fiVt9rXYb0
# processed: rJojfAB5ASw
# processed: f18VWvLxGTg
# processed: eDxcn7Oa_cY
# processed: IdZkBBU-jPw
# processed: fYMiTit2uWo
# processed: nYCJaSQmlZc
# processed: fdBp5PL3VUI
# processed: xxzEY0M4ACU
# processed: 4Fa9we_O3EE
# processed: YeUagM3_NWU
# processed: IdG04mjNQIo
# processed: ibR-tub-bvo
# processed: j-fMRSWYdOE
# processed: 0YnstK85TTY
# processed: flRLS5wGIuU
# processed: K5ggMT2xjHc
# processed: kiX_ePCyUcw
# processed: NHdv-Z6ileA
# processed: I4hW8JxP_eY
# processed: KMnW25Tjxec
# processed: kOOXYu6l_3A
# processed: 8sqXIxw-vFw
# processed: LJV_ZY6rXo8
# processed: jp6UsGiWkMY
# processed: KFm08IY7K4U
# processed: Pjaqv89M1Ec
# processed: KaE4Idtw4gQ
# processed: 70q1ACaN1rY
# processed: M5ZxG9dB2Uw
# processed: UXJtlWJ2M2I
# processed: GrFripBG5kU
# processed: -8AZS2Qgh4E
# processed: P79FgN9gVuY
# processed: 8OlZ-kz6UVM
# processed: K_RHNWYRt4Y
# processed: Uw0EZg_Ibso
# processed: S0IXlmrht9s
# processed: 9uxX_hAF4J0
# processed: g4b3n1Ut6Rk
# processed: CQR12Ju9Ioc
# processed: J32vH_QdQvc
# processed: kSZuMOVproQ
# processed: GSyCE9lCl8I
# processed: S0ij_32q4Cg
# processed: eyR1FIOVH_w
# processed: 7946UplUwTw
# processed: bjAULoqRZ7Y
# processed: Zy5QXwn2jUI
# processed: Nio-apBH-rM
# processed: t_t6uHzJLn4
# processed: qDZtXklSrFs
# processed: hGf4ZD0csB8
# processed: 0K-Zm3SpZ0s
# processed: jigRGcOUu5k
# processed: J2wUwJzJSC0
# processed: Xzb8dQGGf3A
# processed: PzCclzLSqwM
# processed: rEhrCB4sF4A
# processed: c5WslUHjW6A
# processed: KDyJ15XcLEE
# processed: 24btazWmTiw
# processed: i45KWg8Fd2o
# processed: eFqR9r83HQY
# processed: n1uATlI6XDs
# processed: mapeaSfwTMI
# processed: oVQzWGo53gI
# processed: gfE731rDtnU
# processed: 4cP_J-rqH1U
# processed: 8u1MDAevuw8
# processed: -qbXWumy5N4
# processed: ixWk26d0f-A
# processed: IR3E3x27o7E
# processed: dte_sxCIzVg
# processed: Ndd1Z3VDzII
# processed: 8U0qE87nSPw
# processed: U4WyJ1Ovm08
# processed: Y6a8p57vkBo
# processed: 6TihM1hnqdQ
# processed: KDljhTTUecQ
# processed: av91wNVTIa0
# processed: gRQDZmx-VmA
# processed: Uz_3ICeRcM8
# processed: DaRp726Glpw
# processed: Tk1EQ3zckdk
# processed: bek-oje4Hqk
# processed: PEFSBN4uGHA
# processed: Gkm1298qmt4
# processed: 8G7zmK9i00Q
# processed: Ubu_OWVKkdQ
# processed: 2ZemDdHhRAQ
# processed: HwBR9cwrFJI
# processed: wedJEggmTes
# processed: v1amIOL9Vn8
# processed: iGNu_vfnM68
# processed: FRca4VIwDSI
# processed: tF_YNBrhjEw
# processed: nIJxSCPECHc
# processed: 0isrGdB_qUA
# processed: UVjzUBkcKCs
# processed: XRUjpVF_EQ8
# processed: iKV-VWBuELU
# processed: 7IGzuooOGfI
# processed: FF2wSoMG0zk
# processed: SY4D9QUw38g
# processed: iAdS4M8qi04
# processed: Tka94WVSn4k
# processed: 6AMAN8hX7ZI
# processed: 0f60903cU_Q
# processed: 8v_zJEX6wa0
# processed: dOn1gLR6yZw
# processed: UukQSJHNXpY
# processed: rBPoRhcYbRM
# processed: Mr7lvC4I5_A
# processed: NXiLTMDbz8o
# processed: G5pFnPq_xDU
# processed: 0JbgN9lLJ7I
# processed: eU0-gvidb88
# processed: X7euEa9_B14
# processed: 7H4ybE3omqw
# processed: Jq04LTNUGVc
# processed: YfeMWmj0rK0
# processed: kpJO5tjdLNU
# processed: Txxr1iTl5AE
# processed: QHiE1O_8S8A
# processed: 2IAF2e9pG-0
# processed: vT3uWA3WrAg
# processed: pxvNiDZIaC8
# processed: 0-N_TH_-J-s
# processed: U9oP4FAZHy4
# processed: qrZM4JNJSk8
# processed: CxDwuLLabVs
# processed: Dl7kDoNVmRU
# processed: yYRu5B9M0_U
# processed: uYyWpPh9clA
# processed: 7tS7SzWJBpU
# processed: yBl403heGLE
# processed: 1EQyTsKusAw
# processed: hkjVc051tVg
# processed: Tt9r6S5C_fk
# processed: OfrvTYWiV8A
# processed: Qu5pQ65nge0
# processed: zn-_SLVzb34
# processed: 8I2yXJoAQf4
# processed: Ihe3Nom1T34
# processed: ImVI6tDa8No
# processed: IlXCj1gEqrY
# processed: kFEMedBTFHY
# processed: siroPlrkpfA
# processed: l3-TYmAvqlU
# processed: Zf-IMLxIYVA
# processed: -doYIAoRDbM
# processed: XLfDH0zEvjw
# processed: 5H56fj4L47I
# processed: 3SuLqFnnUZs
# processed: pdZ4gXTmV8Y
# processed: WTh-RCUWOUY
# processed: _X2-bsI9G5Q
# processed: GCmp013hqxw
# processed: Ev0m3P4frU8
# processed: c0YOEosIR0s
# processed: jQWGsn28TkE
# processed: 9GK8ETliYZs
# processed: D_SSHGtvgFc
# processed: LktH_DKjk3U
# processed: exh03ovLB2w
# processed: BF4J_jnxAEk
# processed: rxvUxjXKc_c
# processed: O_NPuSfBICs
# processed: e652aU4osHo
# processed: dslnUp7JLog
# processed: bM-L34YamXE
# processed: CcU18LIs41o
# processed: dk0l8HIIC_g
# processed: r-V9g6bPER4
# processed: 7zfiWyRNr7s
# processed: N_Qdsxu2tHs
# processed: FtaTnidcaBU
# processed: QUfLA2NPkOI
# processed: D-I1OAubDn4
# processed: TmVk0BfFC0c
# processed: b621va19wiQ
# processed: _UR1nkwwnAU
# processed: Nv1ZaJ9mL1k
# processed: ScqMUowz1gc
# processed: T_5NQKJn5zw
# processed: sBes_tKsuTk
# processed: v_tGUkrwLXM
# processed: JzjpurCXbzU
# processed: RPepz7XWpPY
# processed: DZtcaaebyeg
# processed: SAESy1HOqFw
# processed: sDZVbfN07tg
# processed: LW0bXncJhIs
# processed: Y7STj3aPW4s
# processed: 7QGjadg5xa8
# processed: B6Ud4rBlFXU
# processed: ZZW5IUcCecs
# processed: 8hDm8l5XNdQ
# processed: R4k3GcbFc8w
# processed: QN5DHvJkYn0
# processed: oCJMmeEFG54
# processed: ubMh47WD2R8
# processed: EKbe1CbY-IA
# processed: AbUGzNBWpuQ
# processed: BFEyGKRq_u0
# processed: pJZvYeJvUnk
# processed: FZXlsuxu3RQ
# processed: AC2t45ivNkU
# processed: eN4_im-O3pg
# processed: evrhcnLIhGI
# processed: z81X5aB2uuc
# processed: DOsHHTpY8Sk
# processed: NthSTng9MHA
# processed: 1_3cdb49RQA
# processed: fzFW3i5g4KY
# processed: m8g_cpJAbKg
# processed: zPw8_j1Rc5Y
# processed: UTNvlys6kk4
# processed: rC0riVEMDxE
# processed: VW_4TagUXmE
# processed: GL5SCwGu1Q4
# processed: ML9Yy31iv1Q
# processed: wzNFLp1kocQ
# processed: VlRKV8d3KmM
# processed: UDIeo0EQI-M
# processed: kUfpfwPbOCo
# processed: XxqoHqu2nDo
# processed: zsXC1K6sPYM
# processed: MbtE4aPjf7o
# processed: DjOJfNZnmjE
# processed: d7daZ_x62fU
# processed: TGszvHKcUnc
# processed: WENS2mbtoV0
# processed: C9k0LLGddzA
# processed: osQrqF0_GTY
# processed: CM9_yhO6blw
# processed: iItnxtB_VEo
# processed: Ra5UcqU2y1E
# processed: Oot6AksTj6M
# processed: l_o9ENkkC14
# processed: vPY2K5WoEHI
# processed: kZy2pJDAxTQ
# processed: cUsx3qxqVDM
# processed: 2oIenzf_iEk
# processed: QVxskMBr78Q
# processed: drgWJjvAO10
# processed: YliSNWslHJI
# processed: YGr9hciY59g
# processed: JYBw8QdNDqQ
# processed: nWEf0-J5Msw
# processed: khAKL_f0wxU
# processed: cmDUozPUaKA
# processed: drpeRSltUvY
# processed: vXaGRYyw78Y
# processed: haErw9pKw1s
# processed: klQX9npEXyw
# processed: Kyc1evjQNlg
# processed: 2FnWtif8fSE
# processed: X-pJNFl58f0
# processed: wfJiuex_ck8
# processed: 48BVHCvXcBM
# processed: fNMPIdkGsgs
# processed: y7_ucTJWMd8
# processed: jaS2eg-GEyA
# processed: vQEi0qddtXY
# processed: Wgo9xoIccbA
# processed: 9NDnlf2_VDg
# processed: JM57qruhbyU
# processed: i8GVAcw0HQ4
# processed: 9BMygbeNxKM
# processed: pXNfuS3Xj20
# processed: hPxlp_vrX7M
# processed: UIH32lKD99A
# processed: SImxYwmjRKY
# processed: H6uWbI5fpLI
# processed: VA0AaJZgsYk
# processed: pjEobnUgEbQ
# processed: KAHXmZMPM1U
# processed: Vr3GdAzSmmM
# processed: 14zWJOfj70k
# processed: ClrB2KShrDI
# processed: j60jtZX36ZY
# processed: g9dxXhnGRW4
# processed: 5fQLJLVkpJM
# processed: YI_vp5j57hY
# processed: l66uYvRQeXU
# processed: d59ifB-6IZE
# processed: N-CyVm2kQ-E
# processed: zb1hpVXw8Hk
# processed: myn2wHEAU18
# processed: DtskQ2bmpa0
# processed: rGwsNXHFdxM
# processed: k_f-BZNSKrg
# processed: B5_lkWA2K7k
# processed: qeybik2wzXE
# processed: t9GZhJ1zD-8
# processed: EjtVrwTF76o
# processed: YW37vrTFPwI
# processed: RB33wNa9Qko
# processed: Ze9ub4hkThs
# processed: 7ykTl04meig
# processed: GrSGIVgppIs
# processed: JbHfYHgb7fE
# processed: sHVPhUcULV4
# processed: K77IzVdTEfg
# processed: JTRE3N_8W_E
# processed: bEVQnLYd9pY
# processed: htfWlRwhTxI
# processed: CtrmPD_z1Yg
# processed: _3gXD3n2yn8
# processed: CeqyuXxbmXw
# processed: yVQKPzpQePA
# processed: 8OVUG8LN1Vo
# processed: tNrbtFyVq7E
# processed: LM3WasPveCI
# processed: snE5gbaS5EQ
# processed: TX_DH0_oozU
# processed: 7N8CMhbnd8I
# processed: ipWJCQLiHdQ
# processed: uwlZP8wkLzU
# processed: r93GPiMZpw0
# processed: DsdHqAvMVM4
# processed: 2P3RFmjGWH0
# processed: xAUrokPODf8
# processed: X_TMRAAprN8
# processed: b9YI9JbKTi4
# processed: D1ZxPnUG1bY
# processed: 7GfDNoYibnM
# processed: 7KgzJMS9M94
# processed: jIGjqPnHPZo
# processed: OCKdUSvKjFo
# processed: 7C1DJOQQAAI
# processed: 8zvQuoKWM_Q
# processed: R47XJPTk1eY
# processed: Z_bM1AgunOA
# processed: AVMpfUnhwro
# processed: riLDZKvN0eY
# processed: gmXr_xq3IqQ
# processed: E27oXzL9bak
# processed: CkKSuaNM51A
# processed: L1UEGNmALy4
# processed: _0iMswBTx-4
# processed: WrdDFSGsAKg
# processed: S-raaxvd4sc
# processed: rGEvWubkGBU
# processed: YPhGqbKq3wg
# processed: t-UaypYmojg
# processed: zP-OZulEbKU
# processed: 7Cm3dXdq0RI
# processed: Hh12lUp6sF4
# processed: mXKWmM1RDVE
# processed: yt3u_mUsUVM
# processed: V2ErISxCkHY
# processed: yV2Rb9PT21M
# processed: cSXbUQqJmU0
# processed: _FDr6FCO19c
# processed: VZByeCKgc7o
# processed: mDU2sGx8Uwc
# processed: kEzAi7XV_Ik
# processed: Qd7kCOQAgR0
# processed: NL3B_vn5NfA
# processed: cci-dY4bDoo
# processed: _zG84prBnu4
# processed: sVgx18Ew99Q
# processed: OCn_i_XIQuQ
# processed: fRQJ78Kao3Y
# processed: XoMQFysgosI
# processed: ro1sRlRv1dg
# processed: zM8vmZeFsyw
# processed: FyXSaqAJmmo
# processed: fuFYqFC2BS8
# processed: l-_RHUBu24o
# processed: oPnhQy-528o
# processed: WKByM-vQvCU
# processed: ngPknEuu35Y
# processed: 2RGTSY8Eihw
# processed: Lz3K70oTJ1k
# processed: BygR-8wg9OE
# processed: KoyhR11Gdoc
# processed: C9ZO3Vz4cd8
# processed: D-6elUM1j-M
# processed: ad1KW9pQwOU
# processed: k_g_Wx2_wl0
# processed: 4SUnF3KThxI
# processed: EQfCR6O1f-k
# processed: Q0kZvhED3_Q
# processed: uuA0o1b6rCs
# processed: XrNEIaco4nA
# processed: HMVifBuGkh8
# processed: XaaDIYk07Io
# processed: 8LxzJOFtW_w
# processed: 83gbotGdoRQ
# processed: n6M0Kl0-6qc
# processed: 0swUuzMLEmQ
# processed: mN-OmjZRybg
# processed: LbLqQFiawHc
# processed: Tqf5659IMUQ
# processed: nh7u5jSimgI
# processed: EMkRE-q8U0c
# processed: lcxFRBQQo9w
# processed: tDYs-G-ZKm0
# processed: VpjKt3sRm6I
# processed: wORClNKuXdk
# processed: YJZB6MqRgMU
# processed: RdwcxK48y0o
# processed: 98DNfBryyiE
# processed: 91lW5qHxzRM
# processed: jxC28DWlngI
# processed: zJmuK_XzPZ8
# processed: 2m4xYGpK6qY
# processed: yc9PA3EEPUs
# processed: N-jVcC3vodk
# processed: KK97Wa_3otU
# processed: OKErGjbGV3M
# processed: fNg8j3WvT2g
# processed: jZTL1PabA8I
# processed: j2dDNgBQoYg
# processed: Ow6NEXieCK8
# processed: a9Qlpwl4QJ4
# processed: DrfIjfLhnpw
# processed: n0jImb6h4BU
# processed: WMyXKJSvy4U
# processed: rflpteSoSDM
# processed: qdNrg2Zyk0Q
# processed: s7p0sq2U50k
# processed: 1Px7dJYPFNM
# processed: 7Gl9bDwu1_E
# processed: 1UGOFgXkSzE
# processed: asmA8NdaMJY
# processed: UwbpPbw0Veg
# processed: PJYShLW8ANE
# processed: sS-BcOjs1IE
# processed: EUhLoh9MX-0
# processed: -c2Zm8Qu-2c
# processed: TKGY-2iXlpk
# processed: yl5A9exT-IY
# processed: LDOycgNRnAg
# processed: fUyGfdGoSlA
# processed: ZteH3X1Si5E
# processed: EKIkrRm_-XU
# processed: AbmVu4wV4-o
# processed: fJgftu_BLYw
# processed: -Oha7YUrdeg
# processed: bEwZmZJQNr4
# processed: JgSJpJNvX0E
# processed: nH_2xYSGg0Y
# processed: 7DiMMeL9Txo
# processed: 658LNFuROI8
# processed: THnUCV27XNA
# processed: 4kUBHND24jQ
# processed: 7ECk5a5G10w
# processed: zXKbreFLHkY
# processed: qkS2pqbd8Mo
# processed: Si19lxqkQyU
# processed: e3oMGD5qbeQ
# processed: 7U9LgQweTn4
# processed: GV6Sd2ec_EA
# processed: EbCOkwFovr4
# processed: yalAhafVuBw
# processed: 2IdzE7yUqpM
# processed: U7Tqr-8Gs3U
# processed: _wRhFe5-Atk
# processed: it-a2KJ7E6k
# processed: 13nU6M4-VYw
# processed: 3bUpj4FzN3E
# processed: hWmEeU7b4_o
# processed: RZPcZqrfFXA
# processed: 2HrgGUA6LD0
# processed: EYEtXWr6UFI
# processed: S1GKOQIIjbs
# processed: wXfRVA6ymaY
# processed: n2iD2mwZ7Ks
# processed: agxERGTJ5Vo
# processed: dX2AYyHW_AE
# processed: jBjjkf_TGbM
# processed: 8-eOYO-H8zk
# processed: g-VctKxDo6E
# processed: NZvDnFv3DE0
# processed: Qjxp3jULfIo
# processed: VdpLxLzilqk
# processed: 2C4GcSrDIxc
# processed: ObOb8S9czns
# processed: MYeRWWdytjU
# processed: Pg9zGucNvIw
# processed: h4DEFEeFutE
# processed: MTsnJyAsFDg
# processed: Cb3VzEsqFo0
# processed: 60uWX731TS8
# processed: yCaRiozeywY
# processed: SlobQhf51dQ
# processed: 7sYfUnej1Tw
# processed: GN2ntd_FPA4
# processed: jdKJomBtwew
# processed: wyea1Sy9wdA
# processed: ZKJQ_Uf0jK8
# processed: da8D5-auGLY
# processed: uhU5Dpr17Nc
# processed: XUqiTEI8abM
# processed: AuHK-OYjhek
# processed: QvnGntmmk3Q
# processed: _NJKPIqFdio
# processed: HopEzPMdhJc
# processed: XT3FbmItezE
# processed: Kq6QjFH9qlU
# processed: gU-P4MIiqT4
# processed: eKQk60bZuW0
# processed: -Kx-_QaEXto
# processed: Puh3e9EuwWw
# processed: n2pF6YdH1ao
# processed: nyPLrYHTfiw
# processed: 8CQsb9z-7VU
# processed: Cn-81fVYvl8
# processed: MKXf29FvuK4
# processed: sJB4TtWCEfE
# processed: 00ELYjo_cQ8
# processed: 5l1kmy8kGn8
# processed: 1czn_HMIV6A
# processed: VJFxDqCOIKI
# processed: jsfHWZo53d0
# processed: EHQvnu0kMTA
# processed: VTEnFhAdrEI
# processed: fj8HBxAA2Jk
# processed: _Wq5eTOZ2io
# processed: cxZsFp4d19o
# processed: G7ECBQJfB-I
# processed: wFPr1BVfbos
# processed: MdbvrVqArGM
# processed: ve0aQiwYiPE
# processed: B7XmzObYHnM
# processed: nj85ZnLI3nQ
# processed: _95dtWva65o
# processed: UrQVjtH-mKo
# processed: u6H82QlGJYw
# processed: simb_9ZlsuM
# processed: 6Sv_8DZ2tAI
# processed: 6voZFFsCBJ8
# processed: 2GiP6-XCPNo
# processed: 6ZGGtdeSIk8
# processed: 0UggFO33Vno
# processed: _aNOMQ4aTLU
# processed: zVoNu0J4FCk
# processed: xHT9EdnmcSM
# processed: aypXpz5gTGE
# processed: 4PsjzKAFBYs
# processed: 08Nl71Z1bG8
# processed: qLzy-9VuMQo
# processed: WiTpeEQbL4k
# processed: euamMVlwN1Y
# processed: TMRFZFznpNI
# processed: f6wrH072ojM
# processed: 4QiOGUAI7O4
# processed: jJ8YdHro8tE
# processed: ox176XdNFvA
# processed: frBZtnlFEf0
# processed: 050_w7RyxUs
# processed: 5unCqbAuEsE
# processed: 8GdPwBTPnQA
# processed: b128C_TJHFw
# processed: 22x-c6FxUrk
# processed: vko5s9XDPlw
# processed: WZJzvUrXrbI
# processed: UOnpwdu0mOY
# processed: 2UstZ0kFlIc
# processed: 5eorDH0hYek
# processed: EeAP60VAxTc
# processed: ZMi4bF-Fn30
# processed: BBZv95OTcow
# processed: z_E2i4Zw72I
# processed: RhERTPQRvvQ
# processed: 8GlY-WoSFYg
# processed: ybYPhB9rBCU
# processed: RA3BDBbf8QQ
# processed: aUn8FIR5fVM
# processed: Ji0uEp4D7gs
# processed: sSBk1t9SyTI
# processed: MUdFIceIpp8
# processed: -Jy9MXAu98I
# processed: G2MWFr9WvNQ
# processed: H8uPH39UUKc
# processed: MsZ-vyWFBU0
# processed: pZXdt8nQ7-Q
# processed: 1KtMLXAR2ZA
# processed: y01ECkYWL5E
# processed: HsnBUPj8r78
# processed: KHLHr4vkbZY
# processed: 90iJ7gqHMrg
# processed: 9BXYPTKHt5o
# processed: QbMpoPbxE-Y
# processed: eZ-AEyAiFD0
# processed: XQXjlH9QfKQ
# processed: nYLvwpYTQIc
# processed: MysbT12Rs98
# processed: zLgnVJA-2nM
# processed: XCAd_JpNWJ4
# processed: josFcOq6K00
# processed: i3lcYapkrPs
# processed: 6OMAyfeGYjg
# processed: kOL1PiF4QHA
# processed: PnPyY_zy_Qc
# processed: _iS7Tl0L15A
# processed: HfYoZbEBlzI
# processed: 2ONRGzQ8ybc
# processed: cVDvRTCsXGY
# processed: 66oAMrstoV4
# processed: 1BsoDu2Nf-8
# processed: YKcBcWnNkXM
# processed: qTjQqO5WwjU
# processed: aFtKRlho_wA
# processed: IX8COtneK8s
# processed: yhWVQiYoJi8
# processed: nstDT5OXr4c
# processed: YmbX6clmDkU
# processed: YdDODmaxb4g
# processed: AiAgZEhGESE
# processed: OsItTUmKWCE
# processed: 5bTbOxELuyY
# processed: zvnrHIxTt64
# processed: zm1JkhyqBS8
# processed: VT1eAa9jL10
# processed: 0DkzFscR1SE
# processed: dMkB-Le2Yko
# processed: 8Uq5KlzPl6Y
# processed: VTHaQ1VrN0k
# processed: 0K_UQpdWTE8
# processed: 9c3CT6vslKI
# processed: apQrFucXih4
# processed: quULWfrxF1Y
# processed: 7rvYRLNPjT0
# processed: y5MwfFIUEeU
# processed: wZmQ7OPhu8w
# processed: BsQqh1nTM54
# processed: mkZQ-kuOPd0
# processed: z6NhI0T-zmw
# processed: z2U6ymBPKfg
# processed: wktfb0lIyY4
# processed: Dq5V8mXAxcs
# processed: GQyLkWcPyDs
# processed: satJ2RUmJY0
# processed: 9g-gnQgBsTM
# processed: T4mRA0TtBt8
# processed: 7VPBqkB3sX0
# processed: gAURwSsGM4k
# processed: iqZpcn4bQEE
# processed: 4kkM_H9ugoE
# processed: mH8_ndN-ibc
# processed: lKBuaEGe1s0
# processed: ckmgWaMiyqk
# processed: MNKJgCttB0c
# processed: wp4HfjbVXNU
# processed: HMwtW0XtivE
# processed: 1mh-uvz-Vso
# processed: WfVqN7gHuJ8
# processed: CW93RColVZA
# processed: 1LsvMFlz7-E
# processed: K6Ytf_ziiPY
# processed: Dr0iHgkYUpA
# processed: eEBIszIDRGA
# processed: tjk72iiUYaU
# processed: hISvGK2oO3c
# processed: CgHnVTFpm_U
# processed: XpcGC7vwUuQ
# processed: 0QEj5GztsaQ
# processed: 0yDv8xDawSw
# processed: u_6LN5L_AEA
# processed: 0ZwHJ9HTKPQ
# processed: GrUB6BPIc70
# processed: 98FOMBc3sUM
# processed: zIUeTuZByX8
# processed: odTuLvuiBbM
# processed: wm2LyTIkI7s
# processed: ePuO-t68iwM
# processed: mzMp8aGROA0
# processed: iVw5OZTurJM
# processed: TFvUqPzRcx8
# processed: 1hjoUUslFI8
# processed: JOTkgZMWPI0
# processed: PT5etqWuLhI
# processed: -bbys8KZYzU
# processed: 0NHyF74-_2Y
# processed: jZIL-Xthi3c
# processed: _wOGNR8NZbI
# processed: tz3C-reBI1Q
# processed: 3oAO1ytXmaE
# processed: vwgd2UFdE6A
# processed: YrKg-opbN1k
# processed: BJv8dBzj2hM
# processed: vK-xYuDfP1E
# processed: YXZgSU1S8K4
# processed: j38dl-qxHXI
# processed: D_58Rtxxdxo
# processed: n2MrXDr92CI
# processed: xYmeKJDltbU
# processed: vDulNsPMKwI
# processed: ZBmgaiH52-o
# processed: khYdzBjKfYo
# processed: uuAV_RXq3SE
# processed: Yj_Vez1prl8
# processed: sD8ppDjyQsk
# processed: -hS8XzclpaE
# processed: CQ7MF9_9mtc
# processed: 2M-MQAn6slY
# processed: 6jZmO4KuNfw
# processed: WQZNuAgDBSQ
# processed: ZbtcCIe1_rc
# processed: 8DDZs0qY_ro
# processed: v8_2qrHqTuQ
# processed: LU7wkOZJAXg
# processed: bl0ejSQ_JBU
# processed: orBySNxe9v8
# processed: 2iFY8GX0KQ0
# processed: v8JRSRTnTh4
# processed: QHsI14pAkTk
# processed: lxR9HKEbR3s
# processed: PLVTDujCDfU
# processed: UxWPfx-J32k
# processed: TC_BqVzeucY
# processed: -ttIMFEufHY
# processed: rruNob27wwM
# processed: oTpph7-SoOU
# processed: JX35XI82iZM
# processed: w-QMpd8a8uQ
# processed: gaAqBq1uxmk
# processed: EUsdkfYMrZs
# processed: ZjyMHW0hm7Y
# processed: V_W_lgiSCd8
# processed: LGdsrg8pPJc
# processed: 8V2xohF_wbw
# processed: rErutpk5-cE
# processed: fkWS24iGV58
# processed: OolUwNFyHow
# processed: Dq-pwGFr7to
# processed: ulhhhamiEb8
# processed: 6t9yOpQB9Fc
# processed: FKkaE0dDGr4
# processed: cxrriUcjrlM
# processed: rWPTSiJCHKw
# processed: Y8VFsmzEMLY
# processed: XC2QkIH22hs
# processed: xe9XXJb3azE
# processed: p0gOQlOO-ME
# processed: LrKtXH_Ox8w
# processed: yH97VujNB_M
# processed: 8RCIHRHiswA
# processed: EbLvXOr5eio
# processed: fEXe5xkfppE
# processed: MYhAh_A6kBc
# processed: c6Yek2AF4OE
# processed: eBbPvC-0DRw
# processed: xx10IJrHgxQ
# processed: cO1akqYXLBI
# processed: WTkJ22YQnx4
# processed: AGlBZqvEIBs
# processed: GWP373_YEW4
# processed: aTZv5bVTeg0
# processed: 3BIUwapdyv8
# processed: FfwDzuH-JpM
# processed: ZNTH02V-7Jg
# processed: F7WaIlVLSS4
# processed: SroLTeW2v4k
# processed: G_PhX_f-Ftw
# processed: ftWX_oUB7JE
# processed: QNCPQMfkkBM
# processed: 0RpPh2G6DhQ
# processed: Rnu7yrwqq1I
# processed: 4B8ej2NA7ZM
# processed: fnoNgG8l2SU
# processed: ZXzV4FAfEds
# processed: vsmznWZfWP0
# processed: W-8Tr7G2cZM
# processed: QOAtrppNPAk
# processed: CAWHhhkg7hs
# processed: TeumABkX_NI
# processed: wtw16ZXtC7Y
# processed: N8k2Yx2ho0M
# processed: mGvK0fz9JQU
# processed: b_LWkDNIZao
# processed: Iaoi5KPAJC8
# processed: ExjXB3yR1kY
# processed: ahMpfif4Q5w
# processed: CMlXVoSHE_E
# processed: TNEc7wt1110
# processed: t1QnbrYDCK4
# processed: kMT4LxKxp_M
# processed: Q0Nrg0RECAg
# processed: mxkJBshxeAg
# processed: 0p7GrLJ8MXk
# processed: yYKaYqeMSA4
# processed: GN5p6m1F1jY
# processed: shU_2vbiwLg
# processed: bVm-VLR6tJs
# processed: Cc_vlsuYuss
# processed: AHj79xK3mus
# processed: ndZi1vMWH5c
# processed: 5tI3xcD2rpQ
# processed: vGdioNe6Xds
# processed: cSFqPdx_aKI
# processed: A4TkG6cWCXc
# processed: CTHcpRCOPlI
# processed: eIMWAWmgzMI
# processed: UakR6JQfhHI
# processed: QuaiTLsxtBk
# processed: L3jZQaaMsx0
# processed: PFucWJLmv6E
# processed: P-7OcgTYo9o
# processed: _dB7ZZmlBX0
# processed: tVXMY7CvhEU
# processed: st5-qboT6DA
# processed: DqBCtmpbLdE
# processed: -NkfQsZiCsg
# processed: 34P-H2xCD4s
# processed: fxq6W0o9L9k
# processed: UwBqZdsyXeM
# processed: 0U0Addz4YEE
# processed: izXnMHwCrJc
# processed: woZ9JgMJCtw
# processed: dDSoczKHY3c
# processed: arAKLtFErVE
# processed: xbdB6X95iGk
# processed: 7xJxI2Vd8fM
# processed: L_aGKmEc1ew
# processed: hfpyvUgAoc4
# processed: kqM7j0XsXIY
# processed: Qa2rbsSqVQs
# processed: _fFINQPcpUk
# processed: Ptow8tEvg5w
# processed: 1NDcqAzDLMk
# processed: GCoPLtXVwJ8
# processed: CS_Ahx5PQEs
# processed: wbdCowB_CTk
# processed: 6RZgrFUEcJs
# processed: vCW5qPrDoQE
# processed: a1-UsXk5gn8
# processed: j6-7hmLGyrY
# processed: Uf4SUVrkQPM
# processed: aaEKIHZ31gE
# processed: eEGRsoV4ju4
# processed: pjrrsjC6F1U
# processed: smQF854PsZ0
# processed: 474hiwuiJYg
# processed: zHUCAdGbAX8
# processed: foMy8iCvIS8
# processed: z0zLTs4UpQg
# processed: r5r0ldW-haQ
# processed: c4dHqLbrZMc
# processed: J6VaSOVF_bc
# processed: n_F0QHqJTP4
# processed: yIHsoSlmq5A
# processed: QqtUBolF6Yw
# processed: BeuL4OrWSbc
# processed: 7sG8cMG7mQE
# processed: YirG1kx3JvU
# processed: mpOM4WM4o_U
# processed: 86tPhcUEjDQ
# processed: s_yQXpL1XNc
# processed: sygDPFaRQNE
# processed: _YXBxehYGDo
# processed: uDAFl1ma5m4
# processed: 61LlSTFAgCM
# processed: NXrmMCUMsC4
# processed: _3s9RmxSnlc
# processed: -gpVTvTqieQ
# processed: kAflPW6eWwg
# processed: hcxo6dIQ6xM
# processed: EsgpWPOSgP8
# processed: ZDCe6_ZKFcw
# processed: oNeUWQzjpgs
# processed: wZWhCM4B33E
# processed: 425yJhQRweI
# processed: NS4TfQc4COs
# processed: zYFX0kss5Go
# processed: svQYw8lW7Sw
# processed: U7yOMrTww6M
# processed: GkfBhPAeB9c
# processed: ka8ZGboobc8
# processed: AEAs6Vi43Vk
# processed: sSOMxpjP57o
# processed: qT_ay2z5Fq8
# processed: B694BSQlUEE
# processed: AgryCGbrxtQ
# processed: 1VB6wc-SGtQ
# processed: DJ5q1HG2HZE
# processed: HAarmLaayt0
# processed: IkEZHJ2L87Y
# processed: jrkdKbcUUnc
# processed: E1KjCb79QaQ
# processed: ymbE4E6WXuM
# processed: tt4cUiD8hR8
# processed: QBSAmn9Jhy8
# processed: y_bAiGtYd6M
# processed: M1Yy3ydacnw
# processed: Cu9PVWM2fJo
# processed: h_LYIFMAuFs
# processed: c-Vh58JlYgk
# processed: UcaAhmgF89w
# processed: 3YisW3CJxBA
# processed: oZSz4BUio64
# processed: EQjkfZHbti8
# ...
# processed: 0m0JRQ-qsbE
# processed: MbIGxwmSBII
# processed: mkpl1dKt-tY
# processed: YGBEH0O_x3E
# processed: tMisTFYOEHk
# processed: r7R3EUUKZT4
# processed: 4ZOdezM12N4
# processed: aBRA3_IyRdE
# processed: ptQae0YktHE
# processed: MHswlXaExh0
# processed: v4qgBjdbB6g
# processed: pSWdPeEehBQ
# processed: GV35Kg4mmZE
# processed: jPuNAxY_JM0
# processed: kLyYNmp6uSk
# processed: Z2WPmfBRwqM
# processed: OHIFn9ndvB8
# processed: GariqC0YPn4
# processed: sX1P5KjeHNY
# processed: -S3aS2Rrg1Q
# processed: nV67ev_HHDU
# processed: WU-PcB4tvVk
# processed: f8KYnJaKocc
# processed: zTa54KS1N1A
# processed: EVA-q3XK47M
# processed: rGbDzFz2l_8
# processed: 9krViilZf9g
# processed: l0cXR2JRCIU
# processed: X6qLO724Dys
# processed: oNJUw6am0B8
# processed: FAbQlI_Y9jA
# processed: uxCZ816zy3w
# processed: v4m1d9Lga-o
# processed: uFgP23DiV8A
# processed: K2goYp0furU
# processed: oDNEFDH_teo
# processed: LO2LsV72Wuk
# processed: Tqutt0d0QwM
# processed: ir1CAr0XXuQ
# processed: 88h-BI7fPQA
# processed: tkqdqE2I3fs
# processed: Lh8BffQJmds
# processed: K2C6dNYoPho
# processed: xidzEdvAnoA
# processed: fLPNPg2DY9A
# processed: UcN1Ts_3ajU
# processed: JmRSdcajpt0
# processed: lTsjpicLlFM
# processed: rcA7Z43CLq4
# processed: fFclOIWoh3M
# processed: 1EPPqwe9cCE
# processed: 9n0zwAbkfZo
# processed: wCCokbL8Y_A
# processed: 6NO6CBxdo9s
# processed: y0YexLX0sK4
# processed: R5kk7GKezT0
# processed: A89PFK8oIc8
# processed: n2LZa_CVCUg
# processed: kgFlDLMZ36s
# processed: qW7wZzRocJw
# processed: d85M3bZZdfE
# processed: 7TS6_IpdtWw
# processed: RqEj3arthkA
# processed: 0nOdsJvq2j4
# processed: 1tidYGb91Gw
# processed: dK2Zr7m3oyU
# processed: uO-wn_I5jcI
# processed: lXjDupjmZTA
# processed: C-6OdkDe8KQ
# processed: JDHz84IORvQ
# processed: 7Xo_QcP05eo
# processed: 5iNVDtgt7V0
# processed: 0F824iRyDJg
# processed: -RZlr1rHk9c
# processed: au56mHNoa7c
# processed: KadqxycIz70
# processed: i0uNb_s3hSs
# processed: OKZJW1k_Fbw
# processed: aK_u6J6abrI
# processed: FE1eXq5_0Mo
# processed: I9ukPI74d1I
# processed: H2uHr4ti79Q
# processed: iExnNjc7QCI
# processed: uGmY5MUqQ5c
# processed: SWE3iIWRfqc
# processed: RaaJVYEW1Wc
# processed: cudJT0Rj42c
# processed: N73Mp7dxvQM
# processed: N-vSd_UUQ-8
# processed: 7vkhmPuRkMg
# processed: eYf_8zGYogA
# processed: KA4HT17bEFc
# processed: B4a-gZxjOBU
# processed: zF8EI4nEj9Q
# processed: ZKdS04irA78
# processed: HF4qxKD33Ow
# processed: hrK22NGZ4Nk
# processed: CU0OeDzrkYk
# processed: PF5GjS4YsFQ
# processed: GBO1OPLLgAk
# processed: 4M8kN5eytEY
# processed: adWfLmLh6Zk
# processed: bbPPp_pHoJs
# processed: 9Sdf-doJGjw
# processed: GObnfNVXIts
# processed: AR_hDlUNIOQ
# processed: djvAFVSwlMc
# processed: fAjt7uKDE3s
# processed: h0ZdQWWbPmg
# processed: lhFoI4AbkfA
# processed: 7jj6G3wLM3Y
# processed: kKXMFFqCSNY
# processed: Aw3XXoAo4qU
# processed: C2OA7bhZIyA
# processed: aiTO72QNUlY
# processed: woocuxfMyQI
# processed: YUiLmO8ZGgs
# processed: Tt7cRIyg4h0
# processed: WXj1tfNoKqs
# processed: 51Ix2vkrryE
# processed: VAWRXUzho4Y
# processed: UQezuimEP_w
# processed: uaR2m_nCLy4
# processed: AWt4RjpmsBc
# processed: 14TckaNkB8A
# processed: yvioBe-zaJQ
# processed: ojTEoVxmPxQ
# processed: WDtDnqUO4vA
# processed: m1_r0bzEpR8
# processed: aBPfMFUcnYM
# processed: jjyqQgVhVOo
# processed: YhCWPTsI83g
# processed: QyRTUdF7Ylg
# processed: wV5BP5r75-I
# processed: SWM5ys6e2Pw
# processed: 9GZORdN2Nhs
# processed: 8qXeu9AqPAw
# processed: ndCaKD965rY
# processed: N4Xk8PLMl-Y
# processed: liEth3GR_t0
# processed: 2KZEsN0vl1M
# processed: CiAvI-64iwc
# processed: peTnnShmju8
# processed: -BmRHTYrVyE
# processed: nnx10U6Bnd4
# processed: GqmeVTB8RH4
# processed: 6oJqgQ8ci6c
# processed: QTcUplmvcIE
# processed: KwbnPs7l7rM
# processed: 9MBFN86sZIU
# processed: vYMd_IB2rt8
# processed: dRxqbf_CeEQ
# processed: mJLUaejwquw
# processed: kqDUW2lKa_0
# processed: gZUSAefzdH0
# processed: o0qfTp0zfxs
# processed: mtGDlPNDzUc
# processed: fxrs1VqlHF8
# processed: 83dV1Bi7tbc
# processed: nRZhq6acL4Q
# processed: 2oyylt-N5I8
# processed: wukFFCnuS04
# processed: vDY1SkfiLqs
# processed: sQmbSdPzgFs
# processed: L3BTidCF1HU
# processed: Eyocus2u9bo
# processed: Is7SpyeGYz0
# processed: 8CGHSXZBQGs
# processed: PoIe5y23CN0
# processed: ioaaOHe0LD0
# processed: Q-IbdTBSvxI
# processed: MmgFDUORgjY
# processed: Ae1DD6Nsys0
# processed: UtDeveHuOL8
# processed: T06V7usNVOU
# processed: -OlZ8V1fiMs
# processed: HtwljCpiKk0
# processed: moZUnhtgzUk
# processed: ArXzbAbv-sQ
# processed: Q3Iu_176a6A
# processed: wWFYxpMPlZE
# processed: i78IPGPp8Nw
# processed: 2MvPmsLdOY4
# processed: vY1KKsb9A3E
# processed: OPqOSE9SZHo
# processed: 37cetF0-YX8
# processed: g1_OJWy3RsA
# processed: qjRvWfGpp4s
# processed: XyIxGNrB1Z8
# processed: 32GjhBzUibg
# processed: eubGDh-ssW4
# processed: tK5fsK-u_KU
# processed: lW7TTIvFMlI
# processed: DUqcOy9WKaY
# processed: gByQUGsowCU
# processed: 0Si8dVAHe1w
# processed: qhv3YtmOwCs
# processed: 5W0gJdhQcTY
# processed: wsyXNBCaMHk
# processed: CigeWu0kr4U
# processed: XnTP1nog1tw
# processed: hyQAxlh6dSs
# processed: JyhltOwRH1M
# processed: hfTBUNUM_UI
# processed: Ramk2hH6E4M
# processed: ViCGK-z95nI
# processed: B_kYJ6fTaNw
# processed: cgo0E0bmMgA
# processed: qtdpnuO4vv8
# processed: qPFNHLa-DJk
# processed: V2Nv9sO4XLM
# processed: urOw8jN03D8
# processed: meBH6LT8lfk
# processed: RTJqSYYSXSo
# processed: mKIR0GLbtLw
# processed: 1n_88IO_Oa0
# processed: pusaPEzCTCY
# processed: 6PHQcUSd4QU
# processed: J9neqMvkk-g
# processed: uG2paQxlON0
# processed: n9HHYY2J8Us
# processed: 62H6sMUEY70
# processed: scXDfCr79GA
# processed: SOl5nhUi1vQ
# processed: BJUzXHVgmmQ
# processed: NopJfK2hDgE
# processed: s4NG7U9JKoo
# processed: HRiP2jQPulY
# processed: gvu2oB5SIAo
# processed: 2oKR-Xy7ycs
# processed: fcc_TY7FnsA
# processed: vfFunSaa0wA
# processed: dpdvHBmPMI8
# processed: MpFRSDRZCmQ
# processed: oe3MKZ6ZOco
# processed: BXgQFZpB1-E
# processed: T6sWjMaRFGc
# processed: fmMUHuafmb4
# processed: bYU709FigjQ
# processed: FfRr_RV7_KY
# processed: xjtBYNuEPCc
# processed: kCtPDf77sVk
# processed: 1Q-j9oZR9Ho
# processed: smTFLaMUix0
# processed: SoWek87KfKA
# processed: GW6cZqBndto
# processed: ZN8BYuv7eZ4
# processed: zLC9YJj393I
# processed: OeCvm17xIn0
# processed: ftBtQ9YfgXE
# processed: YF9n1tm2XcY
# processed: i6k-9cW_vto
# processed: 3vfJkBogSIM
# processed: mb5-3HcoStI
# processed: oOi_e3NK95k
# processed: 2G8cvLUbdjQ
# processed: 33B_b0Fc5tc
# processed: QoQIqq0RtHc
# processed: junQgNw1i-s
# processed: KRjGNqicHWY
# processed: cQiecpwAoqg
# processed: EJlZyB7eHdU
# processed: KvBRxaEj_RM
# processed: -fMDrkE1B7M
# processed: a5Gt0ua1RQQ
# processed: F3iGD_fAZ8c
# processed: Qx7Ln38BQWY
# processed: yThgUMNLZ_w
# processed: CStnC-3wS4M
# processed: 4vOEAtnGqPA
# processed: sa-U648K6JI
# processed: 3tuno6H0KEE
# processed: nrd7jH3YWz4
# processed: Wg8RSgVwWCc
# processed: YOHBon1P1Ww
# processed: OSeiWLI7IuA
# processed: FCvkKRteh9s
# processed: 9Q-jB1zxi_M
# processed: 5MZsXnIkn0I
# processed: 3cA4eBD1ag8
# processed: M8o5aa4gXH4
# processed: tB5ArDZnyog
# processed: er4JdmwBeIY
# processed: wSgAb9z3640
# processed: UD_QGOkran4
# processed: hFtILAQWQhY
# processed: tisOAcrm6nA
# processed: bDHoAVWP6WE
# processed: MjwIQoGnmu8
# processed: wWWgbUtLdz0
# processed: 7b0-VUne0Yw
# processed: McTsoXTfPUs
# processed: SI1AkSh68nk
# processed: W4zr_fW2nVQ
# processed: TjIbtFNV0f8
# processed: nwNkwDtAleI
# processed: dmL2H1FM9K8
# processed: ZcL_8T_y4_A
# processed: Um21_k-aLXs
# processed: wWDVflBjNG8
# processed: l3YYSh7gQYQ
# processed: L7cmfAZ1VQE
# processed: xyH2mlR-8Ls
# processed: 2Ar2rjcdwBg
# processed: jwWTXGB5LKM
# processed: r0jJ-AOKLNc
# processed: ZJdsL9MNmms
# processed: 1zCH5FNBYJI
# processed: yOrfUW4wKx0
# processed: 9O1JOOefORQ
# processed: Gi3R0NQWmFQ
# processed: u3T1oINm0m4
# processed: oxGhhiN3Gaw
# processed: 0gd1BM2NEXk
# processed: ac_JFpTCQW4
# processed: LzX5Xf5JN-E
# processed: NhjR9vIifOI
# processed: 95S765Xe7es
# processed: ANsxUwEzAQM
# processed: 8xWf3G_pXdc
# processed: 8Htj8cFX_wo
# processed: XgIIHJWmADw
# processed: 7WyLrOGfUl0
# processed: DQb7VWyiV1w
# processed: NOJFFNIuIrM
# processed: _1XmhMWjLU0
# processed: 23V2s1-Ed2o
# processed: 5z8sdsHbieM
# processed: ZLHtmXjA0C4
# processed: vyHxlVD8E9k
# processed: Cyhty54p1CY
# processed: 7MFYdNbJQbM
# processed: AHKW_ME16kU
# processed: 9CO8SrKsFmU
# processed: -sq5i4-nVm0
# processed: wRR8HUMdh00
# processed: N1U_nZlhjFE
# processed: BEkIuVYRbZ0
# processed: JD9XO0jt9LI
# processed: J_LjQYjwHJY
# processed: AvlQzRvdrIo
# processed: g5uXrrTIUaQ
# processed: 3LrHFJxFSk8
# processed: aO7455CeNmA
# processed: F3hixYlEa5I
# processed: G26hKnhJBCQ
# processed: MV856hyc1kU
# processed: T02SY6MT2gk
# processed: Gjr3CpBve4M
# processed: RVTvOh1jD00
# processed: B4Xlf8vOvn8
# processed: KjSZKKfL7Qo
# processed: tGKeldMTHmE
# processed: OLGcjMT-YW8
# processed: oQpUN1bjXaU
# processed: gYnUofo4ZOo
# processed: usPQUk45Y2Q
# processed: caGO1JROJqw
# processed: T4YKn7lubBo
# processed: aT1yDdNvono
# processed: jDk29sNyxIE
# processed: wGUYJ6u9f_Y
# processed: ctEOE18flg4
# processed: th9DyAy5VHY
# processed: H2RWRvu6sbg
# processed: FRl_1fjfT8s
# processed: w9irFmLd0nY
# processed: 8J4Mtt19v-c
# processed: g9PmdVQhhdM
# processed: 5IccIxl-6Dw
# processed: _ZbxilnEZL8
# processed: m2dbH0jedoc
# processed: 7ZeekT2uP0g
# processed: gVBGAUzpeRA
# processed: SBR_97ZP5jM
# processed: KfQIn3DdUlQ
# processed: q3VzlCaEpOU
# processed: XK340EehhHo
# processed: f6mu3fixtPM
# processed: biCpQpUGG58
# processed: 6VFNdF2OzGY
# processed: i8iABf4tHZg
# processed: 7aonR9YIYy0
# processed: jjc0pH-fdZQ
# processed: WHJUy7yMm5M
# processed: r_jZfIbxtkA
# processed: w4-cFqIf5gw
# processed: e62kADIdOJ8
# processed: wW-q-eY63-I
# processed: JXEj6rKhEfA
# processed: oQ6cwH7qS3U
# processed: rWTdWS9-Tb0
# processed: nLh5mqWqMIc
# processed: k6T17T1EIIw
# processed: ExZ09hXiLJg
# processed: bqRyYR9qXi4
# processed: 2XCiUgL_M_k
# processed: rc4n3fO3iWk
# processed: -_oeKFVpzCk
# processed: cBtglGXbT3g
# processed: BgCbQJJddBY
# processed: 1XMfTTjrMPo
# processed: zbll_U529WY
# processed: 7oh02P_yhu0
# processed: CiDxGwGeNQ8
# processed: yMvyswSoIow
# processed: WIYjO0ZF_K8
# processed: B7FrbWLiBRo
# processed: lBZk8IXANrg
# processed: CsqeaXRa1KY
# processed: yfhxrSxonds
# processed: oEIW5iEv0Ec
# processed: 8z6pi8kR834
# processed: C1se2UTfK8M
# processed: 8iA3Dx466Sc
# processed: YbqMhWuaBTU
# processed: c5D-snVcO1g
# processed: m5Da__N8M18
# processed: Ssv7bYi9UEA
# processed: 4vWTinhw540
# processed: OSWEor5-DkQ
# processed: z-KOnTHx2vM
# processed: m_03x_S4Ib4
# processed: GS_64crTtfs
# processed: j12TvAddjJs
# processed: dLBCUYXzEbY
# processed: Cn8Dvr-q2jg
# processed: HpwfDRxrEw0
# processed: yzZBKe5IPRs
# processed: gz72kydS2ts
# processed: qBcGcLYeHb0
# processed: OQ1ShK6ZyMw
# processed: ZebniJx0GXU
# processed: pPuLScX4GTk
# processed: J57bShw4gkk
# processed: Jmkq5RLjm0U
# processed: FOzf3JtdBfo
# processed: DG_Fkm_uZZ0
# processed: _N4CoQrXxpc
# processed: ETfgoaaxHwQ
# processed: HADK5_TMa2Q
# processed: tnDC4ZJ0oy8
# processed: QbDXWJh-UYo
# processed: tW0QVDnNcas
# processed: nzFGAQbVqX4
# processed: 9vBDTgj3d58
# processed: lBuyhlNt9AQ
# processed: -wTiaoqSrqs
# processed: yj8LdIodWlM
# processed: Ki-ikKLpu4k
# processed: oPjJ1XzA4bs
# processed: N09sZmuNxyM
# processed: hzGmPbZYkCw
# processed: rVEJ0ZXyRmc
# processed: Cff_oPwUMBw
# processed: 2CKKsRYtekQ
# processed: sTbP3d9P-Lo
# processed: kNwyBP6d2MY
# processed: p7oRbUIDxVg
# processed: dQeQLyue1iA
# processed: _AugcFS3feU
# processed: 1y_SVOBsi4Q
# processed: sGaBVKAPBlc
# processed: JYA6B6oMbvc
# processed: oBs-PE34x7g
# processed: WMP0SmZh1sQ
# processed: 1KRLoHFTqNM
# processed: Mc7gxxm0eRE
# processed: nAPeCpFSm-4
# processed: Udc9cgNjQe4
# processed: 05OnZm5kN9I
# processed: 6gR2rQqAsoI
# processed: YZ4Rdj76M3Y
# processed: jVvBwckK6YE
# processed: he8eh509alA
# processed: aXGld6_-ixg
# processed: 1FXXD8F5wE0
# processed: 9pEdupY0IDk
# processed: HBtBROqwP3Q
# processed: GTQ_s1aH3h8
# processed: RU5HQb7P0Js
# processed: mfaEglP1TOE
# processed: OOv2kR1hGD8
# processed: BrzkPsHXdBE
# processed: gHPces6P4dg
# processed: ViXWQczdYkM
# processed: N8oEA-1g9iU
# processed: -ra-e1RAkgo
# processed: cNfgzbHZR4I
# processed: xe6gvF2nYoI
# processed: KJf2E6yqpUo
# processed: ssA08KKEdG8
# processed: TXbg3ZUsdC8
# processed: AdKVoyPc0xI
# processed: N2phg_qPc-Q
# processed: G7-tJmJwJU8
# processed: M1C5mJsvIBo
# processed: HY7bv6nWkS4
# processed: 9mhp6tcspWQ
# processed: 3vc7BZAo9dA
# processed: AvFHFWu_yYE
# processed: x0GhJxdPyts
# processed: 4ulBjVk6Qqg
# processed: lnCHxre4hrE
# processed: J6Dx436UF1A
# processed: A8E_DYfilis
# processed: -yaDt8YfCRs
# processed: az26Ux-zUS0
# processed: qyo3kReMAYg
# processed: vke-ELgZZuI
# processed: HBWydCNV-fQ
# processed: ZMc8JYarsiU
# processed: 9pOjUYmlJs8
# processed: KS-qTFgQw4c
# processed: RTisLv3gJV8
# processed: YLhQcGIggbM
# processed: kZUibv92B3A
# processed: TJSrSXjedls
# processed: cOlrXPb8mGo
# processed: LvCPmopOwgM
# processed: EFJ98vSCIW0
# processed: e6K0JG1DSAI
# processed: Me7KUr-NOVk
# processed: Gai6fqDobpk
# processed: e2h53DwpbvI
# processed: VmaZo2KtgqU
# processed: Sx43yBjichE
# processed: pNnfChH3nVg
# processed: nkKl3G8AqTw
# processed: P04po-hSlqA
# processed: Yiwa71Gxdf0
# processed: vJaTJSR4JYk
# processed: PlCzc7A9Msw
# processed: XCtGbxgsOfA
# processed: Of6umvEQfN0
# processed: l1qv3YRIEUM
# processed: -oZ1GFVeYiY
# processed: ovdyMeiAohY
# processed: bDHmtz27AxA
# processed: FjKP298SV68
# processed: EmfCItfjs1E
# processed: pUYEhCXFodo
# processed: iw93nIOWE_c
# processed: JqxBAMpVE3Q
# processed: VRuIk9YKws8
# processed: q_85CWRQHdQ
# processed: PPgH-QZ0Tmo
# processed: 3RZtf4VsnV8
# processed: yTuHYsvC828
# processed: L7lYxAmONgk
# processed: k0L0VlF5KOQ
# processed: QkdZOeqJT4M
# processed: 1HH9HPuz5W4
# processed: Ekt20LTewlk
# processed: 1GJY7RkIoaM
# processed: O5Aev0Kk5Lo
# processed: j5jj-Lx9cXw
# processed: wMQHletYNqE
# processed: 9m11MvrJerE
# processed: tLR7LU1Ky8M
# processed: z2L-jDsOte0
# processed: Cu4Izad8PBc
# processed: tFzCfLy1uN8
# processed: VDypI5JpYmc
# processed: niy0OzQTFAw
# processed: Jk9kqla-uVw
# processed: vKJmTpvSUbo
# processed: AhVNPn1oDx4
# processed: BVScYxV7tOk
# processed: gUu1GHGZK78
# processed: 05-hp1fBq6U
# processed: uUwDa-n8Yvk
# processed: ldgHDTsN2No
# processed: cZEl2tPrc3U
# processed: n7PEG3sf67w
# processed: kGbgBljWnQg
# processed: cTr_riX8ySQ
# processed: ik7zs9gnYc0
# processed: 2_0Yu15CgzU
# processed: Zm7tyN8wxS4
# processed: soz1xVYN3Lw
# processed: -oRKObknuAM
# processed: TD2Vg0aD1XQ
# processed: _WvGJkyUrCA
# processed: xPVeCfgaQPM
# processed: GsADjS28LOM
# processed: TxCs8ocpc44
# processed: V8eFbXhsH7c
# processed: X-dsjPmWuco
# processed: ZMlBrxUoZ2I
# processed: EiCbteVYnOQ
# processed: h7tL9GYmwNE
# processed: tXMm5VCs8Hs
# processed: AssCWh2qiRU
# processed: dbNAFywA2gk
# processed: JVA8pCI8r3U
# processed: Ipzm_cNEtFE
# processed: Rz6uGl9odFg
# processed: sqf3CgIH4PY
# processed: KfDWPtKFFJc
# processed: LP7I4ZhR2NQ
# processed: 9td38SjNIoE
# processed: gljdp6aVJzY
# processed: _ITGoI0LfBI
# processed: hpi5cDs-rnU
# processed: 4j5qI97BeHc
# processed: yooUH8JDQow
# processed: N-nOWCVqJZo
# processed: wEAoc-zs-js
# processed: -9KxYWwYqYQ
# processed: 2YaJ3EALHSg
# processed: i3IzUUX4Ri0
# processed: IAVisqabPiE
# processed: 7lZQw9wZWxs
# processed: 5rgw73h5E_8
# processed: ELojJCWO-ts
# processed: Nv4SM7GM4eI
# processed: ATA-8xsgO0A
# processed: 0NMY_B3kvdI
# processed: 3N7CVqdsjec
# processed: icfbQGYGl2I
# processed: nQMEsfOEM2Q
# processed: Ph72i36lAqk
# processed: TybP5BSrLQM
# processed: Ude0gU5X7fI
# processed: e2SP09_a8nk
# processed: RRYIBZmqFW4
# processed: iAxwi26orsE
# processed: JxtoSlAzKxk
# processed: 4mnEGDc4tog
# processed: ZILkFUCGb8o
# processed: B7g0zla28Vc
# processed: BgdOeLaOAvM
# processed: ifBzfAasYCo
# processed: 0nIk99_FT8g
# processed: xBF-uY6juDk
# processed: Fb1orL__srM
# processed: c82q9qHELVE
# processed: LN5lt1JuGcw
# processed: 02_v0ccnjTo
# processed: DcWJGe0qQwg
# processed: lo86oWkCy58
# processed: x2xhnwW7P6M
# processed: oTXa4e0WrQ8
# processed: e1ZO9Ais-J8
# processed: Srk5N4-o2DA
# processed: yS0UQ2ZHfGA
# processed: ywASfmXOkZM
# processed: Mk_kidcFoqw
# processed: ZoY7GtJznvY
# processed: Inv577VRToc
# processed: 5AytrRfp9FI
# processed: ZnUy6ze8uPc
# processed: q1wFPBY6IYI
# processed: EZP0QGWFAf4
# processed: wG6iuVBKLVg
# processed: H54YPD9ojFI
# processed: Mu4zv9DPWOc
# processed: EPtGdhgLuLQ
# processed: NlXehy5ZH3w
# processed: pMucZJgdYZo
# processed: j1PiBbEnICM
# processed: pkCYfLKAiws
# processed: 7jWrpzOez20
# processed: Lzif5nWbIC0
# processed: uwyXNawdKmE
# processed: X7MAD5QVcfU
# processed: e-2RmIng708
# processed: B_ss1KRdPnE
# processed: tBviFkfc_aI
# processed: ylc3_-64Ru8
# processed: UdvM8DlZiSQ
# processed: 0bVieAZfEoU
# processed: PFDUSLRrFxE
# processed: XPRLANjtr5E
# processed: lSLUaBlhKWE
# processed: hSDnLupNhao
# processed: 9ftRJ1VV7UQ
# processed: VuRHqdVsZzw
# processed: zIbgFTgrtGk
# processed: EGFfZmWfwrs
# processed: tzFB0OaTVHw
# processed: mdvMEkVt-GY
# processed: 3gNyNga4Qok
# processed: kiiJIgdIHSs
# processed: sNW784pVjNQ
# processed: VRRGPAqeFbs
# processed: KqIPONa68BY
# processed: AeXxTz8ZZpY
# processed: tWFBltkWhBE
# processed: EeOfSnWpq0U
# processed: yi_pNmmyLKc
# processed: 5l4nsf1fTBk
# processed: OWWzJyHCSok
# processed: GMM205Q2dGQ

# %%
import pandas as pd
from apify_client import ApifyClient

APIFY_TOKEN = "apify_api_aqpjXvfipFAGQN0SaRTjex7ycN03Ws3R25Is"

client = ApifyClient(APIFY_TOKEN)

INPUT_CSV = "/content/instagram_creators.csv"
OUTPUT_CSV = "instagram_creators_table.csv"

# %%
import csv
from apify_client import ApifyClient

# ---------------- CONFIG ----------------
APIFY_TOKEN = "apify_api_9M4RBS2VjNMIAah6WgINIJlG9y8zMR3xFUnt"
ACTOR_ID = "apify/instagram-profile-scraper"

INPUT_CSV = "/content/instagram_creators.csv"
OUTPUT_CSV = "instagram_creators_table.csv"

# ----------------------------------------

client = ApifyClient(APIFY_TOKEN)


def read_usernames(file):
    usernames = []

    with open(file, "r", encoding="utf-8") as f:
        reader = csv.reader(f)

        for i, row in enumerate(reader):

            if not row:
                continue

            username = row[0].strip()

            # skip header row
            if i == 0 and username.lower() == "username":
                continue

            usernames.append(username)

    return usernames

def fetch_profiles(usernames):

    urls = [f"https://www.instagram.com/{u}/" for u in usernames]

    run_input = {
        "directUrls": urls,
        "resultsLimit": len(urls)
    }

    run = client.actor(ACTOR_ID).call(run_input=run_input)

    dataset_id = run["defaultDatasetId"]

    creators = []

    for item in client.dataset(dataset_id).iterate_items():

        creators.append({
            "account_id": item.get("id"),
            "username": item.get("username"),
            "bio": item.get("biography"),
            "followers": item.get("followersCount"),
            "posts": item.get("postsCount"),
            "verified": item.get("verified")
        })

    return creators


def write_creators_table(creators):

    fields = [
        "account_id",
        "username",
        "bio",
        "followers",
        "posts",
        "verified"
    ]

    with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fields)
        writer.writeheader()
        writer.writerows(creators)


def main():

    print("Reading usernames...")
    usernames = read_usernames(INPUT_FILE)

    print(f"Fetching {len(usernames)} Instagram profiles from Apify...")

    creators = fetch_profiles(usernames)

    print(f"Writing {len(creators)} creators to CSV...")

    write_creators_table(creators)

    print("Done. Output saved to:", OUTPUT_FILE)


if __name__ == "__main__":
    main()
# Out:
# Reading usernames...
# Fetching 11825 Instagram profiles from Apify...
# ---------------------------------------------------------------------------
# ApifyApiError                             Traceback (most recent call last)
# /tmp/ipykernel_262/2609996366.py in <cell line: 0>()
#      98
#      99 if __name__ == "__main__":
# --> 100     main()
#
# /tmp/ipykernel_262/2609996366.py in main()
#      88     print(f"Fetching {len(usernames)} Instagram profiles from Apify...")
#      89
# ---> 90     creators = fetch_profiles(usernames)
#      91
#      92     print(f"Writing {len(creators)} creators to CSV...")
#
# /tmp/ipykernel_262/2609996366.py in fetch_profiles(usernames)
#      44     }
#      45
# ---> 46     run = client.actor(ACTOR_ID).call(run_input=run_input)
#      47
#      48     dataset_id = run["defaultDatasetId"]
#
# /usr/local/lib/python3.12/dist-packages/apify_client/_logging.py in wrapper(resource_client, *args, **kwargs)
#      84             log_context.resource_id.set(resource_client.resource_id)
#      85
# ---> 86             return fun(resource_client, *args, **kwargs)
#      87
#      88         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/apify_client/clients/resource_clients/actor.py in call(self, run_input, content_type, build, max_items, max_total_charge_usd, restart_on_error, memory_mbytes, timeout_secs, webhooks, force_permission_level, wait_secs, logger)
#     365             The run object.
#     366         """
# --> 367         started_run = self.start(
#     368             run_input=run_input,
#     369             content_type=content_type,
#
# /usr/local/lib/python3.12/dist-packages/apify_client/_logging.py in wrapper(resource_client, *args, **kwargs)
#      84             log_context.resource_id.set(resource_client.resource_id)
#      85
# ---> 86             return fun(resource_client, *args, **kwargs)
#      87
#      88         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/apify_client/clients/resource_clients/actor.py in start(self, run_input, content_type, build, max_items, max_total_charge_usd, restart_on_error, memory_mbytes, timeout_secs, force_permission_level, wait_for_finish, webhooks)
#     304         )
#     305
# --> 306         response = self.http_client.call(
#     307             url=self._url('runs'),
#     308             method='POST',
#
# /usr/local/lib/python3.12/dist-packages/apify_client/_http_client.py in call(self, method, url, headers, params, data, json, stream, timeout_secs)
#     211             raise ApifyApiError(response, attempt, method=method)
#     212
# --> 213         return retry_with_exp_backoff(
#     214             _make_request,
#     215             max_retries=self.max_retries,
#
# /usr/local/lib/python3.12/dist-packages/apify_client/_utils.py in retry_with_exp_backoff(func, max_retries, backoff_base_millis, backoff_factor, random_factor)
#     173     for attempt in range(1, max_retries + 1):
#     174         try:
# --> 175             return func(stop_retrying, attempt)
#     176         except Exception:
#     177             if not swallow:
#
# /usr/local/lib/python3.12/dist-packages/apify_client/_http_client.py in _make_request(stop_retrying, attempt)
#     209             # Read the response in case it is a stream, so we can raise the error properly
#     210             response.read()
# --> 211             raise ApifyApiError(response, attempt, method=method)
#     212
#     213         return retry_with_exp_backoff(
#
# ApifyApiError: By launching this job you will exceed your remaining usage of $0.002191.  Please consider upgrading to a paid plan at https://console.apify.com/billing/subscription

# %%
f
